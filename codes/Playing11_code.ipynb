# %%
import pandas as pd

# Define the file path
file_path = "/Users/pavanbandaru/Downloads/cricket-squad-selection/Final_dataset_updated.xlsx"

# Load the Excel file
xls = pd.ExcelFile(file_path)

# Get sheet names
sheet_names = xls.sheet_names
sheet_names
# Out:
# ['CSK',
#  'DC',
#  'GT',
#  'KKR',
#  'LSG',
#  'MI',
#  'PBKS',
#  'RCB',
#  'RR',
#  'SRH',
#  'Wicket-Keeper']

# %%
# Load the first sheet (CSK) to inspect its structure
df_csk = pd.read_excel(xls, sheet_name="CSK")

# Display the first few rows
df_csk.head()
# Out:
#        Player       Span  Position  Type  Consistency        Form Team  \
# 0  R Ravindra  2024-2024         2    AR    22.961332   25.420023  CSK
# 1   DP Conway  2022-2023         2   BAT   153.908300  120.680042  CSK
# 2   SM Curran  2019-2024         5    AR    85.724403   32.909673  CSK
# 3   J Overton  2023-2025         6    AR    28.007414   21.414449  CSK
# 4    NT Ellis  2021-2024         8  BOWL    -1.992150   -3.584018  CSK
#
#   Nationality
# 0   Foreginer
# 1   Foreginer
# 2   Foreginer
# 3   Foreginer
# 4   Foreginer

# %% [markdown]
# ## Main Squad Selection Code Best Playing 11

# %%
import pandas as pd

def load_data(file_path):
    """Load the dataset from an Excel file."""
    xls = pd.ExcelFile(file_path)
    sheet_names = xls.sheet_names
    dfs = {sheet: pd.read_excel(xls, sheet_name=sheet) for sheet in sheet_names}
    return dfs

def preprocess_data(dfs):
    """
    For non-wicketkeeper sheets, compute:
      Weighted_Score = 0.3 * Consistency + 0.7 * Form.
    For the Wicket-Keeper sheet, rename 'Consistency_Score' to 'Consistency'
      and compute Weighted_Score similarly.
    """
    for team, df in dfs.items():
        if team != "Wicket-Keeper":
            df["Weighted_Score"] = (0.3 * df["Consistency"]) + (0.7 * df["Form"])
    df_wk = dfs["Wicket-Keeper"]
    df_wk.rename(columns={"Consistency_Score": "Consistency"}, inplace=True)
    df_wk["Weighted_Score"] = (0.3 * df_wk["Consistency"]) + (0.7 * df_wk["Form"])
    return dfs, df_wk

def select_best_players_by_position(df_team):
    """
    For each position from 1 to 11, compare all players in that position and pick
    the candidate with the highest Weighted_Score while ensuring that no more than
    4 'Foreginer' players are selected in total.
    
    If no candidate is found for a given position (under the foreigner constraint),
    a warning is printed and the best candidate ignoring the constraint is selected.
    
    Returns a list of the selected player rows.
    """
    best_players = []
    foreign_count = 0
    
    for pos in range(1, 12):
        candidates = df_team[df_team["Position"] == pos].sort_values(by="Weighted_Score", ascending=False)
        if candidates.empty:
            print(f"Warning: No candidate available for position {pos}.")
            continue
        
        selected = None
        # Try to pick the best candidate that satisfies the foreigner constraint.
        for idx, candidate in candidates.iterrows():
            # Check if candidate is foreigner.
            if str(candidate.get("Nationality", "")).strip().lower() == "foreginer":
                if foreign_count < 4:
                    selected = candidate
                    foreign_count += 1
                    break
                else:
                    # Already reached limit; skip this candidate.
                    continue
            else:
                # Candidate is not foreigner; select immediately.
                selected = candidate
                break
        
        # If no candidate was selected due to constraint (e.g. all are foreigners),
        # fall back to the top candidate ignoring the constraint.
        if selected is None:
            selected = candidates.iloc[0]
            if str(selected.get("Nationality", "")).strip().lower() == "foreginer":
                foreign_count += 1
            print(f"Warning: For position {pos}, all available candidates are foreigners. Selecting the best candidate regardless.")
        
        best_players.append(selected)
    
    return best_players

# Example usage:
file_path = "/Users/pavanbandaru/Downloads/cricket-squad-selection/Copy of Final_dataset_updated(1).xlsx"
dfs = load_data(file_path)
dfs, df_wk = preprocess_data(dfs)

# Select best players by position for team "CSK" with foreigner constraint enforced
df_team = dfs["RR"]  
best_players = select_best_players_by_position(df_team)

print("Best players by dataset Position with at most 4 foreigners:")
# Sorting the output by the dataset's Position
for player in sorted(best_players, key=lambda x: x["Position"]):
    pos = player["Position"]
    bowler_type = player.get("Bowler_Type", "")
    print(f"Position: {pos}, {player['Player']} - {player['Type']} {bowler_type}")
# Out:
# Best players by dataset Position with at most 4 foreigners:
# Position: 1, YBK Jaiswal - BAT nan
# Position: 2, SV Samson - BAT nan
# Position: 3, N Rana - AR Spin
# Position: 4, R Parag - AR Spin
# Position: 5, SO Hetmyer - BAT nan
# Position: 6, DC Jurel - BAT nan
# Position: 7, PW Hasaranga - BOWL Spin
# Position: 8, JC Archer - BOWL Pace
# Position: 9, A Madhwal - BOWL Pace
# Position: 10, M Theekshana - BOWL Spin
# Position: 11, Sandeep Sharma - BOWL Pace

# %% [markdown]
# ## Main Squad Selection Code Best Playing 11

# %%
import pandas as pd

def load_data(file_path):
    """Load the dataset from an Excel file."""
    xls = pd.ExcelFile(file_path)
    sheet_names = xls.sheet_names
    dfs = {sheet: pd.read_excel(xls, sheet_name=sheet) for sheet in sheet_names}
    return dfs

def preprocess_data(dfs):
    """
    For non-wicketkeeper sheets, compute:
      Weighted_Score = 0.3 * Consistency + 0.7 * Form.
    For the Wicket-Keeper sheet, rename 'Consistency_Score' to 'Consistency'
      and compute Weighted_Score similarly.
    """
    for team, df in dfs.items():
        if team != "Wicket-Keeper":
            df["Weighted_Score"] = (0.3 * df["Consistency"]) + (0.7 * df["Form"])
    df_wk = dfs["Wicket-Keeper"]
    df_wk.rename(columns={"Consistency_Score": "Consistency"}, inplace=True)
    df_wk["Weighted_Score"] = (0.3 * df_wk["Consistency"]) + (0.7 * df_wk["Form"])
    return dfs, df_wk

def select_best_players_by_position(df_team):
    """
    For each position from 1 to 11, compare all players in that position and pick
    the candidate with the highest Weighted_Score while ensuring that no more than
    4 'Foreginer' players are selected in total.
    
    If no candidate is found for a given position (under the foreigner constraint),
    a warning is printed and the best candidate ignoring the constraint is selected.
    
    Returns a list of the selected player rows.
    """
    best_players = []
    foreign_count = 0
    
    for pos in range(1, 12):
        candidates = df_team[df_team["Position"] == pos].sort_values(by="Weighted_Score", ascending=False)
        if candidates.empty:
            print(f"Warning: No candidate available for position {pos}.")
            continue
        
        selected = None
        # Try to pick the best candidate that satisfies the foreigner constraint.
        for idx, candidate in candidates.iterrows():
            # Check if candidate is foreigner.
            if str(candidate.get("Nationality", "")).strip().lower() == "foreginer":
                if foreign_count < 4:
                    selected = candidate
                    foreign_count += 1
                    break
                else:
                    # Already reached limit; skip this candidate.
                    continue
            else:
                # Candidate is not foreigner; select immediately.
                selected = candidate
                break
        
        # If no candidate was selected due to constraint (e.g. all are foreigners),
        # fall back to the top candidate ignoring the constraint.
        if selected is None:
            selected = candidates.iloc[0]
            if str(selected.get("Nationality", "")).strip().lower() == "foreginer":
                foreign_count += 1
            print(f"Warning: For position {pos}, all available candidates are foreigners. Selecting the best candidate regardless.")
        
        best_players.append(selected)
    
    return best_players

# Example usage:
file_path = "/Users/pavanbandaru/Downloads/cricket-squad-selection/Copy of Final_dataset_updated(1).xlsx"
dfs = load_data(file_path)
dfs, df_wk = preprocess_data(dfs)

# Select best players by position for team "RR" with foreigner constraint enforced
df_team = dfs["SRH"]  
best_players = select_best_players_by_position(df_team)

print("Best players by dataset Position with at most 4 foreigners:")
# Sorting the output by the dataset's Position
for player in sorted(best_players, key=lambda x: x["Position"]):
    pos = player["Position"]
    bowler_type = player.get("Bowler_Type", "")
    nationality = player.get("Nationality", "N/A")
    print(f"Position: {pos}, {player['Player']} - {player['Type']} {bowler_type} - Nationality: {nationality}")

# --- Additional code to print counts of Indian and Foreigner players ---
indian_count = 0
foreigner_count = 0

for player in best_players:
    # Check the player's nationality (assuming "foreginer" indicates a foreigner)
    if str(player.get("Nationality", "")).strip().lower() == "foreginer":
        foreigner_count += 1
    else:
        indian_count += 1

print("\nPlayer nationality counts:")
print(f"Indian players: {indian_count}")
print(f"Foreigner players: {foreigner_count}")
# Out:
# Best players by dataset Position with at most 4 foreigners:
# Position: 1, Abhishek Sharma - AR Spin - Nationality: Indian
# Position: 2, TM Head - BAT nan - Nationality: Foreginer
# Position: 3, Ishan Kishan - BAT nan - Nationality: Indian
# Position: 4, K Nitish Kumar Reddy - AR Pace - Nationality: Indian
# Position: 5, H Klaasen - BAT nan - Nationality: Foreginer
# Position: 6, A Manohar - BAT nan - Nationality: Indian
# Position: 7, BA Carse - AR Pace - Nationality: Foreginer
# Position: 8, PJ Cummins - AR Pace - Nationality: Foreginer
# Position: 9, HV Patel - AR Pace - Nationality: Indian
# Position: 10, Mohammed Shami - BOWL Pace - Nationality: Indian
# Position: 11, RD Chahar - BOWL Spin - Nationality: Indian
#
# Player nationality counts:
# Indian players: 7
# Foreigner players: 4

# %%
import pandas as pd
import itertools

# Specify the Excel file path and sheet name directly
excel_file_path = "/Users/pavanbandaru/Downloads/cricket-squad-selection/Copy of Final_dataset_updated(1).xlsx"
sheet_name = "CSK"

# Read the Excel file and load the specified sheet into a DataFrame
df = pd.read_excel(excel_file_path, sheet_name=sheet_name)

# Calculate score for each player: Score = 0.7 * Form + 0.3 * Consistency
df['Score'] = 0.7 * df['Form'] + 0.3 * df['Consistency']

# Display players with calculated scores (optional)
print("Players with calculated scores:")
print(df[['Player', 'Position', 'Form', 'Consistency', 'Score']])
print("\n")

# Group players by Position (positions 1 to 11)
positions = range(1, 12)
grouped = {pos: df[df['Position'] == pos].to_dict('records')
           for pos in positions if not df[df['Position'] == pos].empty}

# Display available players per position for verification
for pos in positions:
    count = len(grouped[pos]) if pos in grouped else 0
    print(f"Position {pos}: {count} player(s)")
print("\n")

# Generate all possible squad combinations (one player per position)
all_squads = list(itertools.product(*(grouped[pos] for pos in positions)))
print("Total possible squads (before applying constraints):", len(all_squads))
print("\n")

# Filter squads to meet the constraints:
# - Exactly 4 foreign players (Nationality == "Foreginer")
# - Exactly 1 wicket-keeper (i.e. 'WK' appears in the "Type" column)
valid_squads = []
for squad in all_squads:
    foreign_count = sum(1 for player in squad if player['Nationality'].strip().lower() == 'foreginer')
    wk_count = sum(1 for player in squad if 'WK' in player['Type'])
    if foreign_count == 4 and wk_count == 1:
        valid_squads.append(squad)

print("Total valid squads (with exactly 4 foreign players and 1 wicket-keeper):", len(valid_squads))
print("\n")

# Optionally, display a few sample valid squads with their total scores
print("Sample Valid Squad Combinations:\n")
for idx, squad in enumerate(valid_squads[:5], start=1):
    squad_score = sum(player['Score'] for player in squad)
    print(f"Squad {idx} (Total Score: {squad_score:.2f}):")
    for player in sorted(squad, key=lambda p: p['Position']):
        print(f"  Position {player['Position']}: {player['Player']} - Score: {player['Score']:.2f} | Type: {player['Type']} | Nationality: {player['Nationality']}")
    print()
# Out:
# Players with calculated scores:
#               Player  Position        Form  Consistency       Score
# 0         RD Gaikwad         1  109.460887   344.274000  179.904821
# 1          DP Conway         2  120.680042   153.908300  130.648520
# 2         R Ravindra         3   25.420023    22.961332   24.682416
# 3          V Shankar         3    3.851820     4.837989    4.147671
# 4        RA Tripathi         4   52.947437   322.645800  133.856946
# 5             S Dube         5   42.019424   110.459608   62.551479
# 6           DJ Hooda         5   17.656378   106.662426   44.358192
# 7             V Bedi         5    0.000000     0.000000    0.000000
# 8          SM Curran         6   32.909673    85.724403   48.754092
# 9          J Overton         6   21.414449    28.007414   23.392338
# 10          MS Dhoni         6   72.534903   730.304500  269.865782
# 11          RS Ghosh         7    6.214047    -1.873326    3.787835
# 12         RA Jadeja         7   34.203140   256.421976  100.868791
# 13        SK Rasheed         7   18.377778    51.103930   28.195624
# 14          R Ashwin         8   17.988716   122.584287   49.367388
# 15          NT Ellis         9   -3.584018    -1.992150   -3.106457
# 16           S Gopal         8   -3.324136     7.895505    0.041756
# 17          A Kamboj         8   -8.393370   -12.745300   -9.698949
# 18      KL Nagarkoti         8    6.449213     5.286444    6.100382
# 19        Noor Ahmad         9   13.205177    -0.148060    9.199206
# 20          KK Ahmed        10    0.685826    -1.996050   -0.118737
# 21  Gurjapneet Singh        10   -0.570290    -1.764290   -0.928490
# 22       M Pathirana        11    1.592901     4.720854    2.531287
# 23  Mukesh Choudhary        11  -17.323727    -2.699620  -12.936495
#
#
# Position 1: 1 player(s)
# Position 2: 1 player(s)
# Position 3: 2 player(s)
# Position 4: 1 player(s)
# Position 5: 3 player(s)
# Position 6: 3 player(s)
# Position 7: 3 player(s)
# Position 8: 4 player(s)
# Position 9: 2 player(s)
# Position 10: 2 player(s)
# Position 11: 2 player(s)
#
#
# Total possible squads (before applying constraints): 1728
#
#
# Total valid squads (with exactly 4 foreign players and 1 wicket-keeper): 288
#
#
# Sample Valid Squad Combinations:
#
# Squad 1 (Total Score: 853.97):
#   Position 1: RD Gaikwad - Score: 179.90 | Type: BAT | Nationality: Indian
#   Position 2: DP Conway - Score: 130.65 | Type: BAT | Nationality: Foreginer
#   Position 3: R Ravindra - Score: 24.68 | Type: AR | Nationality: Foreginer
#   Position 4: RA Tripathi - Score: 133.86 | Type: BAT | Nationality: Indian
#   Position 5: S Dube - Score: 62.55 | Type: AR | Nationality: Indian
#   Position 6: MS Dhoni - Score: 269.87 | Type: BAT,WK | Nationality: Indian
#   Position 7: RS Ghosh - Score: 3.79 | Type: AR | Nationality: Indian
#   Position 8: R Ashwin - Score: 49.37 | Type: AR | Nationality: Indian
#   Position 9: NT Ellis - Score: -3.11 | Type: BOWL | Nationality: Foreginer
#   Position 10: KK Ahmed - Score: -0.12 | Type: BOWL | Nationality: Indian
#   Position 11: M Pathirana - Score: 2.53 | Type: BOWL | Nationality: Foreginer
#
# Squad 2 (Total Score: 853.16):
#   Position 1: RD Gaikwad - Score: 179.90 | Type: BAT | Nationality: Indian
#   Position 2: DP Conway - Score: 130.65 | Type: BAT | Nationality: Foreginer
#   Position 3: R Ravindra - Score: 24.68 | Type: AR | Nationality: Foreginer
#   Position 4: RA Tripathi - Score: 133.86 | Type: BAT | Nationality: Indian
#   Position 5: S Dube - Score: 62.55 | Type: AR | Nationality: Indian
#   Position 6: MS Dhoni - Score: 269.87 | Type: BAT,WK | Nationality: Indian
#   Position 7: RS Ghosh - Score: 3.79 | Type: AR | Nationality: Indian
#   Position 8: R Ashwin - Score: 49.37 | Type: AR | Nationality: Indian
#   Position 9: NT Ellis - Score: -3.11 | Type: BOWL | Nationality: Foreginer
#   Position 10: Gurjapneet Singh - Score: -0.93 | Type: BOWL | Nationality: Indian
#   Position 11: M Pathirana - Score: 2.53 | Type: BOWL | Nationality: Foreginer
#
# Squad 3 (Total Score: 866.28):
#   Position 1: RD Gaikwad - Score: 179.90 | Type: BAT | Nationality: Indian
#   Position 2: DP Conway - Score: 130.65 | Type: BAT | Nationality: Foreginer
#   Position 3: R Ravindra - Score: 24.68 | Type: AR | Nationality: Foreginer
#   Position 4: RA Tripathi - Score: 133.86 | Type: BAT | Nationality: Indian
#   Position 5: S Dube - Score: 62.55 | Type: AR | Nationality: Indian
#   Position 6: MS Dhoni - Score: 269.87 | Type: BAT,WK | Nationality: Indian
#   Position 7: RS Ghosh - Score: 3.79 | Type: AR | Nationality: Indian
#   Position 8: R Ashwin - Score: 49.37 | Type: AR | Nationality: Indian
#   Position 9: Noor Ahmad - Score: 9.20 | Type: BOWL | Nationality: Foreginer
#   Position 10: KK Ahmed - Score: -0.12 | Type: BOWL | Nationality: Indian
#   Position 11: M Pathirana - Score: 2.53 | Type: BOWL | Nationality: Foreginer
#
# Squad 4 (Total Score: 865.47):
#   Position 1: RD Gaikwad - Score: 179.90 | Type: BAT | Nationality: Indian
#   Position 2: DP Conway - Score: 130.65 | Type: BAT | Nationality: Foreginer
#   Position 3: R Ravindra - Score: 24.68 | Type: AR | Nationality: Foreginer
#   Position 4: RA Tripathi - Score: 133.86 | Type: BAT | Nationality: Indian
#   Position 5: S Dube - Score: 62.55 | Type: AR | Nationality: Indian
#   Position 6: MS Dhoni - Score: 269.87 | Type: BAT,WK | Nationality: Indian
#   Position 7: RS Ghosh - Score: 3.79 | Type: AR | Nationality: Indian
#   Position 8: R Ashwin - Score: 49.37 | Type: AR | Nationality: Indian
#   Position 9: Noor Ahmad - Score: 9.20 | Type: BOWL | Nationality: Foreginer
#   Position 10: Gurjapneet Singh - Score: -0.93 | Type: BOWL | Nationality: Indian
#   Position 11: M Pathirana - Score: 2.53 | Type: BOWL | Nationality: Foreginer
#
# Squad 5 (Total Score: 804.65):
#   Position 1: RD Gaikwad - Score: 179.90 | Type: BAT | Nationality: Indian
#   Position 2: DP Conway - Score: 130.65 | Type: BAT | Nationality: Foreginer
#   Position 3: R Ravindra - Score: 24.68 | Type: AR | Nationality: Foreginer
#   Position 4: RA Tripathi - Score: 133.86 | Type: BAT | Nationality: Indian
#   Position 5: S Dube - Score: 62.55 | Type: AR | Nationality: Indian
#   Position 6: MS Dhoni - Score: 269.87 | Type: BAT,WK | Nationality: Indian
#   Position 7: RS Ghosh - Score: 3.79 | Type: AR | Nationality: Indian
#   Position 8: S Gopal - Score: 0.04 | Type: BOWL | Nationality: Indian
#   Position 9: NT Ellis - Score: -3.11 | Type: BOWL | Nationality: Foreginer
#   Position 10: KK Ahmed - Score: -0.12 | Type: BOWL | Nationality: Indian
#   Position 11: M Pathirana - Score: 2.53 | Type: BOWL | Nationality: Foreginer

# %%
import pandas as pd
import itertools

# Specify the Excel file path and sheet name directly
excel_file_path = "/Users/pavanbandaru/Downloads/cricket-squad-selection/Copy of Final_dataset_updated(1).xlsx"
sheet_name = "SRH"

# Read the Excel file and load the specified sheet into a DataFrame
df = pd.read_excel(excel_file_path, sheet_name=sheet_name)

# Calculate score for each player: Score = 0.7 * Form + 0.3 * Consistency
df['Score'] = 0.7 * df['Form'] + 0.3 * df['Consistency']

# Optional: Display players with calculated scores
print("Players with calculated scores:")
print(df[['Player', 'Position', 'Form', 'Consistency', 'Score', 'Type', 'Nationality', 'Bowler_Type']])
print("\n")

# Group players by Position (assuming positions 1 to 11)
positions = range(1, 12)
grouped = {pos: df[df['Position'] == pos].to_dict('records')
           for pos in positions if not df[df['Position'] == pos].empty}

# Display available players per position for verification
for pos in positions:
    count = len(grouped[pos]) if pos in grouped else 0
    print(f"Position {pos}: {count} player(s)")
print("\n")

# Generate all possible squad combinations (one player per position)
all_squads = list(itertools.product(*(grouped[pos] for pos in positions)))
print("Total possible squads (before applying constraints):", len(all_squads))
print("\n")

# Filter squads to meet the constraints:
# - Exactly 4 foreign players (Nationality == "Foreginer")
# - Exactly 1 wicket-keeper (i.e. 'WK' appears in the "Type" column)
valid_squads = []
for squad in all_squads:
    foreign_count = sum(1 for player in squad if player['Nationality'].strip().lower() == 'foreginer')
    wk_count = sum(1 for player in squad if 'WK' in player['Type'])
    if foreign_count == 4 and wk_count == 1:
        valid_squads.append(squad)

print("Total valid squads (with exactly 4 foreign players and 1 wicket-keeper):", len(valid_squads))
print("\n")

# Sort valid squads by total squad score in descending order.
# Calculate total squad score as the sum of each player's Score.
valid_squads_sorted = sorted(valid_squads,
                             key=lambda squad: sum(player['Score'] for player in squad),
                             reverse=True)

# Select top 5 squads with the highest total score.
top_squads = valid_squads_sorted[:5]

# Print the top 5 squads with squad details and count of Indian/Foreigner players.
print("Top 5 Squads (by total squad score):\n")
for idx, squad in enumerate(top_squads, start=1):
    squad_score = sum(player['Score'] for player in squad)
    # Count nationality occurrences
    indian_count = sum(1 for player in squad if player['Nationality'].strip().lower() == 'indian')
    foreign_count = sum(1 for player in squad if player['Nationality'].strip().lower() == 'foreginer')
    
    print(f"Squad {idx} (Total Score: {squad_score:.2f}):")
    for player in sorted(squad, key=lambda p: p['Position']):
        print(f"  Position {player['Position']}: {player['Player']} - Score: {player['Score']:.2f} | Type: {player['Type']} | Bowler Type: {player['Bowler_Type']} | Nationality: {player['Nationality']}")
    print(f"  --> Count: Indian = {indian_count}, Foreginer = {foreign_count}\n")
# Out:
# Players with calculated scores:
#                   Player  Position        Form  Consistency       Score  \
# 0        Abhishek Sharma         1   51.931370   106.121999   68.188559
# 1                TM Head         2  116.981217   137.426600  123.114832
# 2                A Taide         2   42.666148    61.802540   48.407066
# 3           Ishan Kishan         3   73.172593   375.057300  163.738005
# 4   K Nitish Kumar Reddy         4   32.626052    29.792531   31.775995
# 5              H Klaasen         5   99.333317   166.108100  119.365752
# 6            Sachin Baby         5   41.745531   193.586500   87.297822
# 7              A Manohar         6   12.739515    55.361600   25.526140
# 8               BA Carse         8   10.983610    15.875320   12.451123
# 9             PJ Cummins         7   27.279144    64.783035   38.530312
# 10              HV Patel         9   11.806267    62.066375   26.884300
# 11        Zeeshan Ansari         9   -9.083030   -14.046000  -10.571921
# 12             E Malinga         9   -9.791256   -14.678885  -11.257545
# 13       Simarjeet Singh         9   -2.981953    -4.621390   -3.473784
# 14        Mohammed Shami        10    5.951384    28.342110   12.668602
# 15            JD Unadkat        10   -3.999132    19.512890    3.054475
# 16               A Zampa         8   -1.618678     2.969093   -0.242346
# 17             RD Chahar        11   -1.590030    13.735780    3.007713
#
#       Type Nationality Bowler_Type
# 0       AR      Indian        Spin
# 1      BAT   Foreginer         NaN
# 2      BAT      Indian         NaN
# 3   BAT,WK      Indian         NaN
# 4       AR      Indian        Pace
# 5   BAT,WK   Foreginer         NaN
# 6      BAT      Indian         NaN
# 7      BAT      Indian         NaN
# 8       AR   Foreginer        Pace
# 9       AR   Foreginer        Pace
# 10      AR      Indian        Pace
# 11    BOWL   Foreginer        Spin
# 12    BOWL   Foreginer        Pace
# 13    BOWL      Indian        Pace
# 14    BOWL      Indian        Pace
# 15    BOWL      Indian        Pace
# 16    BOWL   Foreginer        Spin
# 17    BOWL      Indian        Spin
#
#
# Position 1: 1 player(s)
# Position 2: 2 player(s)
# Position 3: 1 player(s)
# Position 4: 1 player(s)
# Position 5: 2 player(s)
# Position 6: 1 player(s)
# Position 7: 1 player(s)
# Position 8: 2 player(s)
# Position 9: 4 player(s)
# Position 10: 2 player(s)
# Position 11: 1 player(s)
#
#
# Total possible squads (before applying constraints): 64
#
#
# Total valid squads (with exactly 4 foreign players and 1 wicket-keeper): 8
#
#
# Top 5 Squads (by total squad score):
#
# Squad 1 (Total Score: 555.73):
#   Position 1: Abhishek Sharma - Score: 68.19 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 2: TM Head - Score: 123.11 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 3: Ishan Kishan - Score: 163.74 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 4: K Nitish Kumar Reddy - Score: 31.78 | Type: AR | Bowler Type: Pace | Nationality: Indian
#   Position 5: Sachin Baby - Score: 87.30 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 6: A Manohar - Score: 25.53 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 7: PJ Cummins - Score: 38.53 | Type: AR | Bowler Type: Pace | Nationality: Foreginer
#   Position 8: BA Carse - Score: 12.45 | Type: AR | Bowler Type: Pace | Nationality: Foreginer
#   Position 9: Zeeshan Ansari - Score: -10.57 | Type: BOWL | Bowler Type: Spin | Nationality: Foreginer
#   Position 10: Mohammed Shami - Score: 12.67 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: RD Chahar - Score: 3.01 | Type: BOWL | Bowler Type: Spin | Nationality: Indian
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 2 (Total Score: 555.04):
#   Position 1: Abhishek Sharma - Score: 68.19 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 2: TM Head - Score: 123.11 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 3: Ishan Kishan - Score: 163.74 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 4: K Nitish Kumar Reddy - Score: 31.78 | Type: AR | Bowler Type: Pace | Nationality: Indian
#   Position 5: Sachin Baby - Score: 87.30 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 6: A Manohar - Score: 25.53 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 7: PJ Cummins - Score: 38.53 | Type: AR | Bowler Type: Pace | Nationality: Foreginer
#   Position 8: BA Carse - Score: 12.45 | Type: AR | Bowler Type: Pace | Nationality: Foreginer
#   Position 9: E Malinga - Score: -11.26 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   Position 10: Mohammed Shami - Score: 12.67 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: RD Chahar - Score: 3.01 | Type: BOWL | Bowler Type: Spin | Nationality: Indian
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 3 (Total Score: 546.11):
#   Position 1: Abhishek Sharma - Score: 68.19 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 2: TM Head - Score: 123.11 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 3: Ishan Kishan - Score: 163.74 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 4: K Nitish Kumar Reddy - Score: 31.78 | Type: AR | Bowler Type: Pace | Nationality: Indian
#   Position 5: Sachin Baby - Score: 87.30 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 6: A Manohar - Score: 25.53 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 7: PJ Cummins - Score: 38.53 | Type: AR | Bowler Type: Pace | Nationality: Foreginer
#   Position 8: BA Carse - Score: 12.45 | Type: AR | Bowler Type: Pace | Nationality: Foreginer
#   Position 9: Zeeshan Ansari - Score: -10.57 | Type: BOWL | Bowler Type: Spin | Nationality: Foreginer
#   Position 10: JD Unadkat - Score: 3.05 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: RD Chahar - Score: 3.01 | Type: BOWL | Bowler Type: Spin | Nationality: Indian
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 4 (Total Score: 545.43):
#   Position 1: Abhishek Sharma - Score: 68.19 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 2: TM Head - Score: 123.11 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 3: Ishan Kishan - Score: 163.74 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 4: K Nitish Kumar Reddy - Score: 31.78 | Type: AR | Bowler Type: Pace | Nationality: Indian
#   Position 5: Sachin Baby - Score: 87.30 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 6: A Manohar - Score: 25.53 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 7: PJ Cummins - Score: 38.53 | Type: AR | Bowler Type: Pace | Nationality: Foreginer
#   Position 8: BA Carse - Score: 12.45 | Type: AR | Bowler Type: Pace | Nationality: Foreginer
#   Position 9: E Malinga - Score: -11.26 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   Position 10: JD Unadkat - Score: 3.05 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: RD Chahar - Score: 3.01 | Type: BOWL | Bowler Type: Spin | Nationality: Indian
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 5 (Total Score: 543.03):
#   Position 1: Abhishek Sharma - Score: 68.19 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 2: TM Head - Score: 123.11 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 3: Ishan Kishan - Score: 163.74 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 4: K Nitish Kumar Reddy - Score: 31.78 | Type: AR | Bowler Type: Pace | Nationality: Indian
#   Position 5: Sachin Baby - Score: 87.30 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 6: A Manohar - Score: 25.53 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 7: PJ Cummins - Score: 38.53 | Type: AR | Bowler Type: Pace | Nationality: Foreginer
#   Position 8: A Zampa - Score: -0.24 | Type: BOWL | Bowler Type: Spin | Nationality: Foreginer
#   Position 9: Zeeshan Ansari - Score: -10.57 | Type: BOWL | Bowler Type: Spin | Nationality: Foreginer
#   Position 10: Mohammed Shami - Score: 12.67 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: RD Chahar - Score: 3.01 | Type: BOWL | Bowler Type: Spin | Nationality: Indian
#   --> Count: Indian = 7, Foreginer = 4

# %%
import pandas as pd
import itertools

# Specify the Excel file path and sheet name directly
excel_file_path = "/Users/pavanbandaru/Downloads/cricket-squad-selection/Copy of Final_dataset_updated(1).xlsx"
sheet_name = "RCB"  # Change to "RCB" or other sheet as needed

# Read the Excel file and load the specified sheet into a DataFrame
df = pd.read_excel(excel_file_path, sheet_name=sheet_name)

# Calculate score for each player: Score = 0.7 * Form + 0.3 * Consistency
df['Score'] = 0.7 * df['Form'] + 0.3 * df['Consistency']

# Optional: Display players with calculated scores
print("Players with calculated scores:")
print(df[['Player', 'Position', 'Form', 'Consistency', 'Score', 'Type', 'Nationality', 'Bowler_Type']])
print("\n")

# Group players by Position (assuming positions 1 to 11)
positions = range(1, 12)
grouped = {pos: df[df['Position'] == pos].to_dict('records')
           for pos in positions if not df[df['Position'] == pos].empty}

# Display available players per position for verification
for pos in positions:
    count = len(grouped[pos]) if pos in grouped else 0
    print(f"Position {pos}: {count} player(s)")
print("\n")

# Generate all possible squad combinations (one player per position)
all_squads = list(itertools.product(*(grouped[pos] for pos in positions)))
print("Total possible squads (before applying constraints):", len(all_squads))
print("\n")

# Filter squads to meet the constraints:
# - Exactly 4 foreign players (Nationality == "Foreginer")
# - At least one wicketkeeper (i.e. 'WK' appears in the "Type" column)
valid_squads = []
for squad in all_squads:
    foreign_count = sum(1 for player in squad if player['Nationality'].strip().lower() == 'foreginer')
    wk_count = sum(1 for player in squad if 'WK' in player['Type'])
    if foreign_count == 4 and wk_count >= 1:
        valid_squads.append(squad)

print("Total valid squads (with exactly 4 foreign players and at least 1 wicketkeeper):", len(valid_squads))
print("\n")

# Force inclusion of HV Patel if he is in the dataset.
if "HV Patel" in df['Player'].values:
    valid_squads = [squad for squad in valid_squads if any(player['Player'] == 'HV Patel' for player in squad)]
    print("After forcing inclusion of HV Patel, valid squads:", len(valid_squads))
    print("\n")

# Sort valid squads by total squad score in descending order.
valid_squads_sorted = sorted(valid_squads,
                             key=lambda squad: sum(player['Score'] for player in squad),
                             reverse=True)

# Select top 5 squads with the highest total score.
top_squads = valid_squads_sorted[:5]

if not top_squads:
    print("No valid squads found meeting all criteria (including HV Patel if present).")
else:
    # Print the top 5 squads with squad details and counts of Indian/Foreigner players.
    print("Top 5 Squads (by total squad score):\n")
    for idx, squad in enumerate(top_squads, start=1):
        squad_score = sum(player['Score'] for player in squad)
        # Count nationality occurrences
        indian_count = sum(1 for player in squad if player['Nationality'].strip().lower() == 'indian')
        foreign_count = sum(1 for player in squad if player['Nationality'].strip().lower() == 'foreginer')
        
        print(f"Squad {idx} (Total Score: {squad_score:.2f}):")
        for player in sorted(squad, key=lambda p: p['Position']):
            print(f"  Position {player['Position']}: {player['Player']} - Score: {player['Score']:.2f} | Type: {player['Type']} | Bowler Type: {player['Bowler_Type']} | Nationality: {player['Nationality']}")
        print(f"  --> Count: Indian = {indian_count}, Foreginer = {foreign_count}\n")
# Out:
# Players with calculated scores:
#             Player  Position        Form  Consistency       Score    Type  \
# 0   LS Livingstone         4   21.392604    77.716706   38.289834      AR
# 1       R Shepherd         7   22.694281    20.728633   22.104586      AR
# 2      MS Bhandage         6    7.693454    16.143654   10.228514      AR
# 3        KH Pandya         7   22.823990   145.633904   59.666964      AR
# 4    Swapnil Singh         8   20.610524    12.807622   18.269653      AR
# 5          PD Salt         1   97.855912   121.416700  104.924148  BAT,WK
# 6         TH David         6   65.436768   120.975700   82.098447     BAT
# 7       D Padikkal         3   19.237172   120.817100   49.711151     BAT
# 8       SS Chikara         2    9.550107     8.686780    9.291109     BAT
# 9       RM Patidar         3   88.992590   138.074400  103.717133     BAT
# 10         V Kohli         2  133.657600  1087.267000  419.740420     BAT
# 11       JM Sharma         5   51.119763   124.918600   73.259414  BAT,WK
# 12      N Thushara         9  -12.951069   -15.775040  -13.798260    BOWL
# 13         L Ngidi        10   -3.141651     2.160578   -1.550982    BOWL
# 14    JR Hazlewood        11   -3.508667     3.830991   -1.306770    BOWL
# 15         B Kumar         8   33.866449    43.731870   36.826075    BOWL
# 16    Rasikh Salam         9   -2.521690    -6.720070   -3.781204    BOWL
# 17   Suyash Sharma        10  -14.811352    -6.076660  -12.190945    BOWL
# 18      Yash Dayal        10   -0.284155    -0.394590   -0.317286    BOWL
# 19    Mohit Rathee        11  -15.119889   -22.633300  -17.373913    BOWL
#
#    Nationality Bowler_Type
# 0    Foreginer        Spin
# 1    Foreginer        Pace
# 2       Indian        Pace
# 3       Indian        Spin
# 4       Indian        Spin
# 5    Foreginer         NaN
# 6    Foreginer         NaN
# 7       Indian         NaN
# 8       Indian         NaN
# 9       Indian         NaN
# 10      Indian         NaN
# 11      Indian         NaN
# 12   Foreginer        Pace
# 13   Foreginer        Pace
# 14   Foreginer        Pace
# 15      Indian        Pace
# 16      Indian        Pace
# 17      Indian        Spin
# 18      Indian        Pace
# 19      Indian        Spin
#
#
# Position 1: 1 player(s)
# Position 2: 2 player(s)
# Position 3: 2 player(s)
# Position 4: 1 player(s)
# Position 5: 1 player(s)
# Position 6: 2 player(s)
# Position 7: 2 player(s)
# Position 8: 2 player(s)
# Position 9: 2 player(s)
# Position 10: 3 player(s)
# Position 11: 2 player(s)
#
#
# Total possible squads (before applying constraints): 384
#
#
# Total valid squads (with exactly 4 foreign players and at least 1 wicketkeeper): 128
#
#
# Top 5 Squads (by total squad score):
#
# Squad 1 (Total Score: 913.12):
#   Position 1: PD Salt - Score: 104.92 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 419.74 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 103.72 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: LS Livingstone - Score: 38.29 | Type: AR | Bowler Type: Spin | Nationality: Foreginer
#   Position 5: JM Sharma - Score: 73.26 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 82.10 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 59.67 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: B Kumar - Score: 36.83 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 9: Rasikh Salam - Score: -3.78 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 10: Yash Dayal - Score: -0.32 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: JR Hazlewood - Score: -1.31 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 2 (Total Score: 901.24):
#   Position 1: PD Salt - Score: 104.92 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 419.74 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 103.72 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: LS Livingstone - Score: 38.29 | Type: AR | Bowler Type: Spin | Nationality: Foreginer
#   Position 5: JM Sharma - Score: 73.26 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 82.10 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 59.67 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: B Kumar - Score: 36.83 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 9: Rasikh Salam - Score: -3.78 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 10: Suyash Sharma - Score: -12.19 | Type: BOWL | Bowler Type: Spin | Nationality: Indian
#   Position 11: JR Hazlewood - Score: -1.31 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 3 (Total Score: 895.82):
#   Position 1: PD Salt - Score: 104.92 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 419.74 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 103.72 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: LS Livingstone - Score: 38.29 | Type: AR | Bowler Type: Spin | Nationality: Foreginer
#   Position 5: JM Sharma - Score: 73.26 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 82.10 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 59.67 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: B Kumar - Score: 36.83 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 9: Rasikh Salam - Score: -3.78 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 10: L Ngidi - Score: -1.55 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   Position 11: Mohit Rathee - Score: -17.37 | Type: BOWL | Bowler Type: Spin | Nationality: Indian
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 4 (Total Score: 894.56):
#   Position 1: PD Salt - Score: 104.92 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 419.74 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 103.72 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: LS Livingstone - Score: 38.29 | Type: AR | Bowler Type: Spin | Nationality: Foreginer
#   Position 5: JM Sharma - Score: 73.26 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 82.10 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 59.67 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: Swapnil Singh - Score: 18.27 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 9: Rasikh Salam - Score: -3.78 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 10: Yash Dayal - Score: -0.32 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: JR Hazlewood - Score: -1.31 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 5 (Total Score: 887.03):
#   Position 1: PD Salt - Score: 104.92 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 419.74 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 103.72 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: LS Livingstone - Score: 38.29 | Type: AR | Bowler Type: Spin | Nationality: Foreginer
#   Position 5: JM Sharma - Score: 73.26 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 82.10 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 59.67 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: B Kumar - Score: 36.83 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 9: N Thushara - Score: -13.80 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   Position 10: Yash Dayal - Score: -0.32 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: Mohit Rathee - Score: -17.37 | Type: BOWL | Bowler Type: Spin | Nationality: Indian
#   --> Count: Indian = 7, Foreginer = 4

# %% [markdown]
# ### Final Squad code

# %%
import pandas as pd
import itertools

# Specify the Excel file path and sheet name directly
excel_file_path = "/Users/pavanbandaru/Downloads/cricket-squad-selection/Copy of Final_dataset_updated(1).xlsx"
sheet_name = "RCB" 

# Read the Excel file and load the specified sheet into a DataFrame
df = pd.read_excel(excel_file_path, sheet_name=sheet_name)

# Calculate score for each player: Score = 0.7 * Form + 0.3 * Consistency
df['Score'] = 0.7 * df['Form'] + 0.3 * df['Consistency']

# Optional: Display players with calculated scores
print("Players with calculated scores:")
print(df[['Player', 'Position', 'Form', 'Consistency', 'Score', 'Type', 'Nationality', 'Bowler_Type']])
print("\n")

# Group players by Position (assuming positions 1 to 11)
positions = range(1, 12)
grouped = {pos: df[df['Position'] == pos].to_dict('records')
           for pos in positions if not df[df['Position'] == pos].empty}

# Display available players per position for verification
for pos in positions:
    count = len(grouped[pos]) if pos in grouped else 0
    print(f"Position {pos}: {count} player(s)")
print("\n")

# Generate all possible squad combinations (one player per position)
all_squads = list(itertools.product(*(grouped[pos] for pos in positions)))
print("Total possible squads (before applying constraints):", len(all_squads))
print("\n")

# Filter squads to meet the constraints:
# - Exactly 4 foreign players (Nationality == "Foreginer")
# - At least one wicketkeeper (i.e. 'WK' appears in the "Type" column)
valid_squads = []
for squad in all_squads:
    foreign_count = sum(1 for player in squad if player['Nationality'].strip().lower() == 'foreginer')
    wk_count = sum(1 for player in squad if 'WK' in player['Type'])
    if foreign_count == 4 and wk_count >= 1:
        valid_squads.append(squad)

print("Total valid squads (with exactly 4 foreign players and at least 1 wicketkeeper):", len(valid_squads))
print("\n")

# Sort valid squads by total squad score in descending order.
valid_squads_sorted = sorted(valid_squads,
                             key=lambda squad: sum(player['Score'] for player in squad),
                             reverse=True)

# Select top 5 squads with the highest total score.
top_squads = valid_squads_sorted[:5]

if not top_squads:
    print("No valid squads found meeting all criteria.")
else:
    # Print the top 5 squads with squad details and counts of Indian/Foreigner players.
    print("Top 5 Squads (by total squad score):\n")
    for idx, squad in enumerate(top_squads, start=1):
        squad_score = sum(player['Score'] for player in squad)
        # Count nationality occurrences
        indian_count = sum(1 for player in squad if player['Nationality'].strip().lower() == 'indian')
        foreign_count = sum(1 for player in squad if player['Nationality'].strip().lower() == 'foreginer')
        
        print(f"Squad {idx} (Total Score: {squad_score:.2f}):")
        for player in sorted(squad, key=lambda p: p['Position']):
            print(f"  Position {player['Position']}: {player['Player']} - Score: {player['Score']:.2f} | Type: {player['Type']} | Bowler Type: {player['Bowler_Type']} | Nationality: {player['Nationality']}")
        print(f"  --> Count: Indian = {indian_count}, Foreginer = {foreign_count}\n")
# Out:
# Players with calculated scores:
#             Player  Position        Form  Consistency       Score    Type  \
# 0          PD Salt         1   97.855912   121.416700  104.924148  BAT,WK
# 1       SS Chikara         2    9.550107     8.686780    9.291109     BAT
# 2          V Kohli         2  133.657600  1087.267000  419.740420     BAT
# 3       D Padikkal         3   19.237172   120.817100   49.711151     BAT
# 4       RM Patidar         3   88.992590   138.074400  103.717133     BAT
# 5   LS Livingstone         4   21.392604    77.716706   38.289834      AR
# 6        JM Sharma         5   51.119763   124.918600   73.259414  BAT,WK
# 7      MS Bhandage         6    7.693454    16.143654   10.228514      AR
# 8         TH David         6   65.436768   120.975700   82.098447     BAT
# 9       R Shepherd         7   22.694281    20.728633   22.104586      AR
# 10       KH Pandya         7   22.823990   145.633904   59.666964      AR
# 11   Swapnil Singh         8   20.610524    12.807622   18.269653      AR
# 12         B Kumar         8   33.866449    43.731870   36.826075    BOWL
# 13      N Thushara         9  -12.951069   -15.775040  -13.798260    BOWL
# 14    Rasikh Salam         9   -2.521690    -6.720070   -3.781204    BOWL
# 15         L Ngidi        10   -3.141651     2.160578   -1.550982    BOWL
# 16   Suyash Sharma        10  -14.811352    -6.076660  -12.190945    BOWL
# 17      Yash Dayal        10   -0.284155    -0.394590   -0.317286    BOWL
# 18    JR Hazlewood        11   -3.508667     3.830991   -1.306770    BOWL
# 19    Mohit Rathee        11  -15.119889   -22.633300  -17.373913    BOWL
#
#    Nationality Bowler_Type
# 0    Foreginer         NaN
# 1       Indian         NaN
# 2       Indian         NaN
# 3       Indian         NaN
# 4       Indian         NaN
# 5    Foreginer        Spin
# 6       Indian         NaN
# 7       Indian        Pace
# 8    Foreginer         NaN
# 9    Foreginer        Pace
# 10      Indian        Spin
# 11      Indian        Spin
# 12      Indian        Pace
# 13   Foreginer        Pace
# 14      Indian        Pace
# 15   Foreginer        Pace
# 16      Indian        Spin
# 17      Indian        Pace
# 18   Foreginer        Pace
# 19      Indian        Spin
#
#
# Position 1: 1 player(s)
# Position 2: 2 player(s)
# Position 3: 2 player(s)
# Position 4: 1 player(s)
# Position 5: 1 player(s)
# Position 6: 2 player(s)
# Position 7: 2 player(s)
# Position 8: 2 player(s)
# Position 9: 2 player(s)
# Position 10: 3 player(s)
# Position 11: 2 player(s)
#
#
# Total possible squads (before applying constraints): 384
#
#
# Total valid squads (with exactly 4 foreign players and at least 1 wicketkeeper): 128
#
#
# Top 5 Squads (by total squad score):
#
# Squad 1 (Total Score: 913.12):
#   Position 1: PD Salt - Score: 104.92 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 419.74 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 103.72 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: LS Livingstone - Score: 38.29 | Type: AR | Bowler Type: Spin | Nationality: Foreginer
#   Position 5: JM Sharma - Score: 73.26 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 82.10 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 59.67 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: B Kumar - Score: 36.83 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 9: Rasikh Salam - Score: -3.78 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 10: Yash Dayal - Score: -0.32 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: JR Hazlewood - Score: -1.31 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 2 (Total Score: 901.24):
#   Position 1: PD Salt - Score: 104.92 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 419.74 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 103.72 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: LS Livingstone - Score: 38.29 | Type: AR | Bowler Type: Spin | Nationality: Foreginer
#   Position 5: JM Sharma - Score: 73.26 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 82.10 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 59.67 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: B Kumar - Score: 36.83 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 9: Rasikh Salam - Score: -3.78 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 10: Suyash Sharma - Score: -12.19 | Type: BOWL | Bowler Type: Spin | Nationality: Indian
#   Position 11: JR Hazlewood - Score: -1.31 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 3 (Total Score: 895.82):
#   Position 1: PD Salt - Score: 104.92 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 419.74 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 103.72 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: LS Livingstone - Score: 38.29 | Type: AR | Bowler Type: Spin | Nationality: Foreginer
#   Position 5: JM Sharma - Score: 73.26 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 82.10 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 59.67 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: B Kumar - Score: 36.83 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 9: Rasikh Salam - Score: -3.78 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 10: L Ngidi - Score: -1.55 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   Position 11: Mohit Rathee - Score: -17.37 | Type: BOWL | Bowler Type: Spin | Nationality: Indian
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 4 (Total Score: 894.56):
#   Position 1: PD Salt - Score: 104.92 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 419.74 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 103.72 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: LS Livingstone - Score: 38.29 | Type: AR | Bowler Type: Spin | Nationality: Foreginer
#   Position 5: JM Sharma - Score: 73.26 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 82.10 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 59.67 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: Swapnil Singh - Score: 18.27 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 9: Rasikh Salam - Score: -3.78 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 10: Yash Dayal - Score: -0.32 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: JR Hazlewood - Score: -1.31 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 5 (Total Score: 887.03):
#   Position 1: PD Salt - Score: 104.92 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 419.74 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 103.72 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: LS Livingstone - Score: 38.29 | Type: AR | Bowler Type: Spin | Nationality: Foreginer
#   Position 5: JM Sharma - Score: 73.26 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 82.10 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 59.67 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: B Kumar - Score: 36.83 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 9: N Thushara - Score: -13.80 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   Position 10: Yash Dayal - Score: -0.32 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: Mohit Rathee - Score: -17.37 | Type: BOWL | Bowler Type: Spin | Nationality: Indian
#   --> Count: Indian = 7, Foreginer = 4

# %%
import pandas as pd
import itertools

# Specify the Excel file path and sheet name directly
excel_file_path = "/Users/pavanbandaru/Downloads/cricket-squad-selection/Copy of Final_dataset_updated(1).xlsx"
sheet_name = "CSK"  # Change to "RCB" or other sheet as needed

# Read the Excel file and load the specified sheet into a DataFrame
df = pd.read_excel(excel_file_path, sheet_name=sheet_name)

# Calculate each player's score using the weighted sum (MCDM approach)
# Weight: 70% for Form and 30% for Consistency.
df['Score'] = 0.7 * df['Form'] + 0.3 * df['Consistency']

# Optional: Display players with calculated scores
print("Players with calculated scores:")
print(df[['Player', 'Position', 'Form', 'Consistency', 'Score', 'Type', 'Nationality', 'Bowler_Type']])
print("\n")

# Group players by Position (assuming positions 1 to 11)
positions = range(1, 12)
grouped = {pos: df[df['Position'] == pos].to_dict('records')
           for pos in positions if not df[df['Position'] == pos].empty}

# Display available players per position for verification
for pos in positions:
    count = len(grouped[pos]) if pos in grouped else 0
    print(f"Position {pos}: {count} player(s)")
print("\n")

# Generate all possible squad combinations (one player per position)
all_squads = list(itertools.product(*(grouped[pos] for pos in positions)))
print("Total possible squads (before applying constraints):", len(all_squads))
print("\n")

# Filter squads to meet the constraints:
# - Exactly 4 foreign players (Nationality == "Foreginer")
# - At least one wicketkeeper (i.e. 'WK' appears in the "Type" column)
valid_squads = []
for squad in all_squads:
    foreign_count = sum(1 for player in squad if player['Nationality'].strip().lower() == 'foreginer')
    wk_count = sum(1 for player in squad if 'WK' in player['Type'])
    if foreign_count == 4 and wk_count >= 1:
        valid_squads.append(squad)

print("Total valid squads (with exactly 4 foreign players and at least 1 wicketkeeper):", len(valid_squads))
print("\n")

# ------------------------------
# MCDM: Weighted Sum Model for Squad Ranking
# ------------------------------
def compute_mcdm_score(squad):
    """
    Compute the aggregated squad score using a weighted sum model.
    Here, each player's score (computed as 0.7*Form + 0.3*Consistency)
    is summed up to represent the squad's overall performance.
    """
    return sum(player['Score'] for player in squad)

# Sort valid squads by the computed MCDM score (total squad score) in descending order.
valid_squads_sorted = sorted(valid_squads, key=compute_mcdm_score, reverse=True)

# Select top 5 squads with the highest aggregated (MCDM) score.
top_squads = valid_squads_sorted[:5]

if not top_squads:
    print("No valid squads found meeting all criteria.")
else:
    # Print the top 5 squads with details and counts of Indian/Foreigner players.
    print("Top 5 Squads (by total squad score using MCDM):\n")
    for idx, squad in enumerate(top_squads, start=1):
        squad_score = compute_mcdm_score(squad)
        # Count nationality occurrences
        indian_count = sum(1 for player in squad if player['Nationality'].strip().lower() == 'indian')
        foreign_count = sum(1 for player in squad if player['Nationality'].strip().lower() == 'foreginer')
        
        print(f"Squad {idx} (Total Score: {squad_score:.2f}):")
        for player in sorted(squad, key=lambda p: p['Position']):
            print(f"  Position {player['Position']}: {player['Player']} - Score: {player['Score']:.2f} | Type: {player['Type']} | Bowler Type: {player['Bowler_Type']} | Nationality: {player['Nationality']}")
        print(f"  --> Count: Indian = {indian_count}, Foreginer = {foreign_count}\n")
# Out:
# Players with calculated scores:
#               Player  Position        Form  Consistency       Score    Type  \
# 0         RD Gaikwad         1  109.460887   344.274000  179.904821     BAT
# 1          DP Conway         2  120.680042   153.908300  130.648520     BAT
# 2         R Ravindra         3   25.420023    22.961332   24.682416      AR
# 3          V Shankar         3    3.851820     4.837989    4.147671      AR
# 4        RA Tripathi         4   52.947437   322.645800  133.856946     BAT
# 5             S Dube         5   42.019424   110.459608   62.551479      AR
# 6           DJ Hooda         5   17.656378   106.662426   44.358192      AR
# 7             V Bedi         5    0.000000     0.000000    0.000000  BAT,WK
# 8          SM Curran         6   32.909673    85.724403   48.754092      AR
# 9          J Overton         6   21.414449    28.007414   23.392338      AR
# 10          MS Dhoni         6   72.534903   730.304500  269.865782  BAT,WK
# 11          RS Ghosh         7    6.214047    -1.873326    3.787835      AR
# 12         RA Jadeja         7   34.203140   256.421976  100.868791      AR
# 13        SK Rasheed         7   18.377778    51.103930   28.195624     BAT
# 14          R Ashwin         8   17.988716   122.584287   49.367388      AR
# 15          NT Ellis         9   -3.584018    -1.992150   -3.106457    BOWL
# 16           S Gopal         8   -3.324136     7.895505    0.041756    BOWL
# 17          A Kamboj         8   -8.393370   -12.745300   -9.698949    BOWL
# 18      KL Nagarkoti         8    6.449213     5.286444    6.100382      AR
# 19        Noor Ahmad         9   13.205177    -0.148060    9.199206    BOWL
# 20          KK Ahmed        10    0.685826    -1.996050   -0.118737    BOWL
# 21  Gurjapneet Singh        10   -0.570290    -1.764290   -0.928490    BOWL
# 22       M Pathirana        11    1.592901     4.720854    2.531287    BOWL
# 23  Mukesh Choudhary        11  -17.323727    -2.699620  -12.936495    BOWL
#
#    Nationality Bowler_Type
# 0       Indian         NaN
# 1    Foreginer         NaN
# 2    Foreginer        Spin
# 3       Indian        Pace
# 4       Indian         NaN
# 5       Indian        Pace
# 6       Indian        Spin
# 7       Indian         NaN
# 8    Foreginer        Pace
# 9    Foreginer        Pace
# 10      Indian         NaN
# 11      Indian        Pace
# 12      Indian        Spin
# 13      Indian         NaN
# 14      Indian        Spin
# 15   Foreginer        Pace
# 16      Indian        Spin
# 17      Indian        Pace
# 18      Indian        Pace
# 19   Foreginer        Spin
# 20      Indian        Pace
# 21      Indian        Pace
# 22   Foreginer        Pace
# 23      Indian        Pace
#
#
# Position 1: 1 player(s)
# Position 2: 1 player(s)
# Position 3: 2 player(s)
# Position 4: 1 player(s)
# Position 5: 3 player(s)
# Position 6: 3 player(s)
# Position 7: 3 player(s)
# Position 8: 4 player(s)
# Position 9: 2 player(s)
# Position 10: 2 player(s)
# Position 11: 2 player(s)
#
#
# Total possible squads (before applying constraints): 1728
#
#
# Total valid squads (with exactly 4 foreign players and at least 1 wicketkeeper): 336
#
#
# Top 5 Squads (by total squad score using MCDM):
#
# Squad 1 (Total Score: 963.36):
#   Position 1: RD Gaikwad - Score: 179.90 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 2: DP Conway - Score: 130.65 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 3: R Ravindra - Score: 24.68 | Type: AR | Bowler Type: Spin | Nationality: Foreginer
#   Position 4: RA Tripathi - Score: 133.86 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 5: S Dube - Score: 62.55 | Type: AR | Bowler Type: Pace | Nationality: Indian
#   Position 6: MS Dhoni - Score: 269.87 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 7: RA Jadeja - Score: 100.87 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: R Ashwin - Score: 49.37 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 9: Noor Ahmad - Score: 9.20 | Type: BOWL | Bowler Type: Spin | Nationality: Foreginer
#   Position 10: KK Ahmed - Score: -0.12 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: M Pathirana - Score: 2.53 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 2 (Total Score: 962.55):
#   Position 1: RD Gaikwad - Score: 179.90 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 2: DP Conway - Score: 130.65 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 3: R Ravindra - Score: 24.68 | Type: AR | Bowler Type: Spin | Nationality: Foreginer
#   Position 4: RA Tripathi - Score: 133.86 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 5: S Dube - Score: 62.55 | Type: AR | Bowler Type: Pace | Nationality: Indian
#   Position 6: MS Dhoni - Score: 269.87 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 7: RA Jadeja - Score: 100.87 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: R Ashwin - Score: 49.37 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 9: Noor Ahmad - Score: 9.20 | Type: BOWL | Bowler Type: Spin | Nationality: Foreginer
#   Position 10: Gurjapneet Singh - Score: -0.93 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: M Pathirana - Score: 2.53 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 3 (Total Score: 951.05):
#   Position 1: RD Gaikwad - Score: 179.90 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 2: DP Conway - Score: 130.65 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 3: R Ravindra - Score: 24.68 | Type: AR | Bowler Type: Spin | Nationality: Foreginer
#   Position 4: RA Tripathi - Score: 133.86 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 5: S Dube - Score: 62.55 | Type: AR | Bowler Type: Pace | Nationality: Indian
#   Position 6: MS Dhoni - Score: 269.87 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 7: RA Jadeja - Score: 100.87 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: R Ashwin - Score: 49.37 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 9: NT Ellis - Score: -3.11 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   Position 10: KK Ahmed - Score: -0.12 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: M Pathirana - Score: 2.53 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 4 (Total Score: 950.24):
#   Position 1: RD Gaikwad - Score: 179.90 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 2: DP Conway - Score: 130.65 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 3: R Ravindra - Score: 24.68 | Type: AR | Bowler Type: Spin | Nationality: Foreginer
#   Position 4: RA Tripathi - Score: 133.86 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 5: S Dube - Score: 62.55 | Type: AR | Bowler Type: Pace | Nationality: Indian
#   Position 6: MS Dhoni - Score: 269.87 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 7: RA Jadeja - Score: 100.87 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: R Ashwin - Score: 49.37 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 9: NT Ellis - Score: -3.11 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   Position 10: Gurjapneet Singh - Score: -0.93 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: M Pathirana - Score: 2.53 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 5 (Total Score: 945.16):
#   Position 1: RD Gaikwad - Score: 179.90 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 2: DP Conway - Score: 130.65 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 3: R Ravindra - Score: 24.68 | Type: AR | Bowler Type: Spin | Nationality: Foreginer
#   Position 4: RA Tripathi - Score: 133.86 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 5: DJ Hooda - Score: 44.36 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 6: MS Dhoni - Score: 269.87 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 7: RA Jadeja - Score: 100.87 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: R Ashwin - Score: 49.37 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 9: Noor Ahmad - Score: 9.20 | Type: BOWL | Bowler Type: Spin | Nationality: Foreginer
#   Position 10: KK Ahmed - Score: -0.12 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: M Pathirana - Score: 2.53 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4

# %% [markdown]
# ### Final code for squad selection using MCDM

# %%
import pandas as pd
import numpy as np
import itertools

# Specify the Excel file path and sheet name directly
excel_file_path = "/Users/pavanbandaru/Downloads/cricket-squad-selection/Copy of Final_dataset_updated(1).xlsx"
sheet_name = "CSK"  # Change as needed

# Read the Excel file and load the specified sheet into a DataFrame
df = pd.read_excel(excel_file_path, sheet_name=sheet_name)

# Define the criteria to be used in TOPSIS
criteria = ['Form', 'Consistency']

# Extract the decision matrix from the DataFrame
decision_matrix = df[criteria].values.astype(float)

# Normalize the decision matrix using vector normalization
norm_denominator = np.sqrt((decision_matrix ** 2).sum(axis=0))
norm_matrix = decision_matrix / norm_denominator

# Define weights for the criteria (same as before: 0.7 for Form, 0.3 for Consistency)
weights = np.array([0.7, 0.3])

# Create the weighted normalized decision matrix
weighted_norm_matrix = norm_matrix * weights

# Determine the ideal (best) and anti-ideal (worst) solutions
# For beneficial criteria, ideal is max and anti-ideal is min.
ideal_solution = weighted_norm_matrix.max(axis=0)
anti_ideal_solution = weighted_norm_matrix.min(axis=0)

# Calculate the Euclidean distance from each alternative to the ideal and anti-ideal solutions
distance_to_ideal = np.sqrt(((weighted_norm_matrix - ideal_solution) ** 2).sum(axis=1))
distance_to_anti_ideal = np.sqrt(((weighted_norm_matrix - anti_ideal_solution) ** 2).sum(axis=1))

# Compute the TOPSIS score (relative closeness to the ideal solution)
df['TOPSIS_Score'] = distance_to_anti_ideal / (distance_to_ideal + distance_to_anti_ideal)

# For comparison, you can also keep the weighted sum score if desired.
df['Weighted_Sum_Score'] = 0.7 * df['Form'] + 0.3 * df['Consistency']

# Display players with calculated TOPSIS and weighted sum scores
print("Players with TOPSIS and Weighted Sum Scores:")
print(df[['Player', 'Position', 'Form', 'Consistency', 'Weighted_Sum_Score', 'TOPSIS_Score', 'Type', 'Nationality', 'Bowler_Type']])
print("\n")

# Group players by Position (assuming positions 1 to 11)
positions = range(1, 12)
grouped = {pos: df[df['Position'] == pos].to_dict('records')
           for pos in positions if not df[df['Position'] == pos].empty}

# Display available players per position for verification
for pos in positions:
    count = len(grouped[pos]) if pos in grouped else 0
    print(f"Position {pos}: {count} player(s)")
print("\n")

# Generate all possible squad combinations (one player per position)
all_squads = list(itertools.product(*(grouped[pos] for pos in positions)))
print("Total possible squads (before applying constraints):", len(all_squads))
print("\n")

# Filter squads to meet the constraints:
# - Exactly 4 foreign players (Nationality == "Foreginer")
# - At least one wicketkeeper (i.e. 'WK' appears in the "Type" column)
valid_squads = []
for squad in all_squads:
    foreign_count = sum(1 for player in squad if player['Nationality'].strip().lower() == 'foreginer')
    wk_count = sum(1 for player in squad if 'WK' in player['Type'])
    if foreign_count == 4 and wk_count >= 1:
        valid_squads.append(squad)

print("Total valid squads (with exactly 4 foreign players and at least 1 wicketkeeper):", len(valid_squads))
print("\n")

# Now, sort valid squads by total squad TOPSIS score in descending order.
valid_squads_sorted = sorted(valid_squads,
                             key=lambda squad: sum(player['TOPSIS_Score'] for player in squad),
                             reverse=True)

# Select top 5 squads with the highest total TOPSIS score.
top_squads = valid_squads_sorted[:5]

if not top_squads:
    print("No valid squads found meeting all criteria.")
else:
    print("Top 5 Squads (by total TOPSIS score):\n")
    for idx, squad in enumerate(top_squads, start=1):
        squad_score = sum(player['TOPSIS_Score'] for player in squad)
        # Count nationality occurrences
        indian_count = sum(1 for player in squad if player['Nationality'].strip().lower() == 'indian')
        foreign_count = sum(1 for player in squad if player['Nationality'].strip().lower() == 'foreginer')
        
        print(f"Squad {idx} (Total TOPSIS Score: {squad_score:.4f}):")
        for player in sorted(squad, key=lambda p: p['Position']):
            print(f"  Position {player['Position']}: {player['Player']} - TOPSIS Score: {player['TOPSIS_Score']:.4f} | Type: {player['Type']} | Bowler Type: {player['Bowler_Type']} | Nationality: {player['Nationality']}")
        print(f"  --> Count: Indian = {indian_count}, Foreginer = {foreign_count}\n")
# Out:
# Players with TOPSIS and Weighted Sum Scores:
#               Player  Position        Form  Consistency  Weighted_Sum_Score  \
# 0         RD Gaikwad         1  109.460887   344.274000          179.904821
# 1          DP Conway         2  120.680042   153.908300          130.648520
# 2         R Ravindra         3   25.420023    22.961332           24.682416
# 3          V Shankar         3    3.851820     4.837989            4.147671
# 4        RA Tripathi         4   52.947437   322.645800          133.856946
# 5             S Dube         5   42.019424   110.459608           62.551479
# 6           DJ Hooda         5   17.656378   106.662426           44.358192
# 7             V Bedi         5    0.000000     0.000000            0.000000
# 8          SM Curran         6   32.909673    85.724403           48.754092
# 9          J Overton         6   21.414449    28.007414           23.392338
# 10          MS Dhoni         6   72.534903   730.304500          269.865782
# 11          RS Ghosh         7    6.214047    -1.873326            3.787835
# 12         RA Jadeja         7   34.203140   256.421976          100.868791
# 13        SK Rasheed         7   18.377778    51.103930           28.195624
# 14          R Ashwin         8   17.988716   122.584287           49.367388
# 15          NT Ellis         9   -3.584018    -1.992150           -3.106457
# 16           S Gopal         8   -3.324136     7.895505            0.041756
# 17          A Kamboj         8   -8.393370   -12.745300           -9.698949
# 18      KL Nagarkoti         8    6.449213     5.286444            6.100382
# 19        Noor Ahmad         9   13.205177    -0.148060            9.199206
# 20          KK Ahmed        10    0.685826    -1.996050           -0.118737
# 21  Gurjapneet Singh        10   -0.570290    -1.764290           -0.928490
# 22       M Pathirana        11    1.592901     4.720854            2.531287
# 23  Mukesh Choudhary        11  -17.323727    -2.699620          -12.936495
#
#     TOPSIS_Score    Type Nationality Bowler_Type
# 0       0.778407     BAT      Indian         NaN
# 1       0.723394     BAT   Foreginer         NaN
# 2       0.270847      AR   Foreginer        Spin
# 3       0.136288      AR      Indian        Pace
# 4       0.497786     BAT      Indian         NaN
# 5       0.383326      AR      Indian        Pace
# 6       0.237144      AR      Indian        Spin
# 7       0.111643  BAT,WK      Indian         NaN
# 8       0.325106      AR   Foreginer        Pace
# 9       0.247259      AR   Foreginer        Pace
# 10      0.701152  BAT,WK      Indian         NaN
# 11      0.150617      AR      Indian        Pace
# 12      0.371187      AR      Indian        Spin
# 13      0.231793     BAT      Indian         NaN
# 14      0.242530      AR      Indian        Spin
# 15      0.088777    BOWL   Foreginer        Pace
# 16      0.091232    BOWL      Indian        Spin
# 17      0.057605    BOWL      Indian        Pace
# 18      0.152614      AR      Indian        Pace
# 19      0.194159    BOWL   Foreginer        Spin
# 20      0.115849    BOWL      Indian        Pace
# 21      0.107918    BOWL      Indian        Pace
# 22      0.122054    BOWL   Foreginer        Pace
# 23      0.005987    BOWL      Indian        Pace
#
#
# Position 1: 1 player(s)
# Position 2: 1 player(s)
# Position 3: 2 player(s)
# Position 4: 1 player(s)
# Position 5: 3 player(s)
# Position 6: 3 player(s)
# Position 7: 3 player(s)
# Position 8: 4 player(s)
# Position 9: 2 player(s)
# Position 10: 2 player(s)
# Position 11: 2 player(s)
#
#
# Total possible squads (before applying constraints): 1728
#
#
# Total valid squads (with exactly 4 foreign players and at least 1 wicketkeeper): 336
#
#
# Top 5 Squads (by total TOPSIS score):
#
# Squad 1 (Total TOPSIS Score: 4.4007):
#   Position 1: RD Gaikwad - TOPSIS Score: 0.7784 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 2: DP Conway - TOPSIS Score: 0.7234 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 3: R Ravindra - TOPSIS Score: 0.2708 | Type: AR | Bowler Type: Spin | Nationality: Foreginer
#   Position 4: RA Tripathi - TOPSIS Score: 0.4978 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 5: S Dube - TOPSIS Score: 0.3833 | Type: AR | Bowler Type: Pace | Nationality: Indian
#   Position 6: MS Dhoni - TOPSIS Score: 0.7012 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 7: RA Jadeja - TOPSIS Score: 0.3712 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: R Ashwin - TOPSIS Score: 0.2425 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 9: Noor Ahmad - TOPSIS Score: 0.1942 | Type: BOWL | Bowler Type: Spin | Nationality: Foreginer
#   Position 10: KK Ahmed - TOPSIS Score: 0.1158 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: M Pathirana - TOPSIS Score: 0.1221 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 2 (Total TOPSIS Score: 4.3928):
#   Position 1: RD Gaikwad - TOPSIS Score: 0.7784 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 2: DP Conway - TOPSIS Score: 0.7234 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 3: R Ravindra - TOPSIS Score: 0.2708 | Type: AR | Bowler Type: Spin | Nationality: Foreginer
#   Position 4: RA Tripathi - TOPSIS Score: 0.4978 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 5: S Dube - TOPSIS Score: 0.3833 | Type: AR | Bowler Type: Pace | Nationality: Indian
#   Position 6: MS Dhoni - TOPSIS Score: 0.7012 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 7: RA Jadeja - TOPSIS Score: 0.3712 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: R Ashwin - TOPSIS Score: 0.2425 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 9: Noor Ahmad - TOPSIS Score: 0.1942 | Type: BOWL | Bowler Type: Spin | Nationality: Foreginer
#   Position 10: Gurjapneet Singh - TOPSIS Score: 0.1079 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: M Pathirana - TOPSIS Score: 0.1221 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 3 (Total TOPSIS Score: 4.3108):
#   Position 1: RD Gaikwad - TOPSIS Score: 0.7784 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 2: DP Conway - TOPSIS Score: 0.7234 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 3: R Ravindra - TOPSIS Score: 0.2708 | Type: AR | Bowler Type: Spin | Nationality: Foreginer
#   Position 4: RA Tripathi - TOPSIS Score: 0.4978 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 5: S Dube - TOPSIS Score: 0.3833 | Type: AR | Bowler Type: Pace | Nationality: Indian
#   Position 6: MS Dhoni - TOPSIS Score: 0.7012 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 7: RA Jadeja - TOPSIS Score: 0.3712 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: KL Nagarkoti - TOPSIS Score: 0.1526 | Type: AR | Bowler Type: Pace | Nationality: Indian
#   Position 9: Noor Ahmad - TOPSIS Score: 0.1942 | Type: BOWL | Bowler Type: Spin | Nationality: Foreginer
#   Position 10: KK Ahmed - TOPSIS Score: 0.1158 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: M Pathirana - TOPSIS Score: 0.1221 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 4 (Total TOPSIS Score: 4.3028):
#   Position 1: RD Gaikwad - TOPSIS Score: 0.7784 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 2: DP Conway - TOPSIS Score: 0.7234 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 3: R Ravindra - TOPSIS Score: 0.2708 | Type: AR | Bowler Type: Spin | Nationality: Foreginer
#   Position 4: RA Tripathi - TOPSIS Score: 0.4978 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 5: S Dube - TOPSIS Score: 0.3833 | Type: AR | Bowler Type: Pace | Nationality: Indian
#   Position 6: MS Dhoni - TOPSIS Score: 0.7012 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 7: RA Jadeja - TOPSIS Score: 0.3712 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: KL Nagarkoti - TOPSIS Score: 0.1526 | Type: AR | Bowler Type: Pace | Nationality: Indian
#   Position 9: Noor Ahmad - TOPSIS Score: 0.1942 | Type: BOWL | Bowler Type: Spin | Nationality: Foreginer
#   Position 10: Gurjapneet Singh - TOPSIS Score: 0.1079 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: M Pathirana - TOPSIS Score: 0.1221 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 5 (Total TOPSIS Score: 4.2953):
#   Position 1: RD Gaikwad - TOPSIS Score: 0.7784 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 2: DP Conway - TOPSIS Score: 0.7234 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 3: R Ravindra - TOPSIS Score: 0.2708 | Type: AR | Bowler Type: Spin | Nationality: Foreginer
#   Position 4: RA Tripathi - TOPSIS Score: 0.4978 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 5: S Dube - TOPSIS Score: 0.3833 | Type: AR | Bowler Type: Pace | Nationality: Indian
#   Position 6: MS Dhoni - TOPSIS Score: 0.7012 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 7: RA Jadeja - TOPSIS Score: 0.3712 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: R Ashwin - TOPSIS Score: 0.2425 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 9: NT Ellis - TOPSIS Score: 0.0888 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   Position 10: KK Ahmed - TOPSIS Score: 0.1158 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: M Pathirana - TOPSIS Score: 0.1221 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4

# %%
import pandas as pd
import itertools

# Input and output file paths
input_excel_file = "/Users/pavanbandaru/Downloads/cricket-squad-selection/Copy of Final_dataset_updated(1).xlsx"
output_excel_file = "/Users/pavanbandaru/Downloads/cricket-squad-selection/Output_squads.xlsx"

# Read all sheets from the Excel file into a dictionary {sheet_name: DataFrame}
sheets_dict = pd.read_excel(input_excel_file, sheet_name=None)

# Dictionary to hold output DataFrames for each sheet
output_dfs = {}

# Process each sheet individually
for sheet_name, df in sheets_dict.items():
    # Calculate score for each player: Score = 0.7 * Form + 0.3 * Consistency
    df['Score'] = 0.7 * df['Form'] + 0.3 * df['Consistency']
    
    # Define positions 1 to 11
    positions = range(1, 12)
    grouped = {}
    missing_position = False
    for pos in positions:
        players_at_pos = df[df['Position'] == pos].to_dict('records')
        if not players_at_pos:
            missing_position = True
            break
        grouped[pos] = players_at_pos
    
    # If any required position is missing, record a message and continue to next sheet.
    if missing_position:
        output_dfs[sheet_name] = pd.DataFrame({
            "Message": [f"Missing players for some positions. Cannot form a complete squad in sheet '{sheet_name}'."]
        })
        continue
    
    # Generate all possible squad combinations (one player per position)
    all_squads = list(itertools.product(*(grouped[pos] for pos in positions)))
    
    # Filter squads based on constraints:
    # - Exactly 4 foreign players (Nationality == "Foreginer")
    # - At least one wicketkeeper (i.e., 'WK' in the "Type" column)
    valid_squads = []
    for squad in all_squads:
        foreign_count = sum(1 for player in squad if player['Nationality'].strip().lower() == 'foreginer')
        wk_count = sum(1 for player in squad if 'WK' in player['Type'])
        if foreign_count == 4 and wk_count >= 1:
            valid_squads.append(squad)
            
    if not valid_squads:
        output_dfs[sheet_name] = pd.DataFrame({
            "Message": [f"No valid squads found meeting criteria in sheet '{sheet_name}'."]
        })
        continue

    # Sort valid squads by total squad score in descending order and select the top 5 squads.
    valid_squads_sorted = sorted(valid_squads,
                                 key=lambda squad: sum(player['Score'] for player in squad),
                                 reverse=True)
    top_squads = valid_squads_sorted[:5]
    
    # Prepare a list of rows containing squad and player details
    rows = []
    for squad_idx, squad in enumerate(top_squads, start=1):
        squad_total_score = sum(player['Score'] for player in squad)
        indian_count = sum(1 for player in squad if player['Nationality'].strip().lower() == 'indian')
        foreign_count = sum(1 for player in squad if player['Nationality'].strip().lower() == 'foreginer')
        # Sort players by their position for clarity
        for player in sorted(squad, key=lambda p: p['Position']):
            row = {
                'Squad_Number': squad_idx,
                'Squad_Total_Score': squad_total_score,
                'Position': player['Position'],
                'Player': player['Player'],
                'Form': player['Form'],
                'Consistency': player['Consistency'],
                'Player_Score': player['Score'],
                'Type': player['Type'],
                'Bowler_Type': player['Bowler_Type'],
                'Nationality': player['Nationality'],
                'Indian_Count': indian_count,
                'Foreigner_Count': foreign_count
            }
            rows.append(row)
    
    # Convert rows into a DataFrame and sort by Squad_Number (ensuring grouping)
    out_df = pd.DataFrame(rows)
    out_df.sort_values("Squad_Number", inplace=True)
    output_dfs[sheet_name] = out_df

# Write all output DataFrames to a new Excel file with each sheet retaining its own data.
# Also, apply a unique background color for each squad group if the "Squad_Number" column exists.
with pd.ExcelWriter(output_excel_file, engine='xlsxwriter') as writer:
    # Define a list of colors for squads (colors will repeat if more than the list length)
    squad_colors = ['#FFC7CE', '#C6EFCE', '#FFEB9C', '#BDD7EE', '#D9D2E9', '#FCE4D6', '#E2EFDA', '#D9E1F2']
    
    for sheet, out_df in output_dfs.items():
        out_df.to_excel(writer, sheet_name=sheet, index=False)
        workbook = writer.book
        worksheet = writer.sheets[sheet]
        
        # Only apply formatting if "Squad_Number" exists
        if "Squad_Number" in out_df.columns:
            for squad_num, group in out_df.groupby('Squad_Number'):
                color = squad_colors[(int(squad_num) - 1) % len(squad_colors)]
                cell_format = workbook.add_format({'bg_color': color})
                # Apply the format to each row in this group
                for df_index in group.index:
                    excel_row = df_index + 1  # Adjust for header row
                    worksheet.set_row(excel_row, None, cell_format)

print(f"Output with colored squads written to {output_excel_file}")
# Out:
# Output with colored squads written to /Users/pavanbandaru/Downloads/cricket-squad-selection/Output_squads.xlsx

# %%
import pandas as pd
import itertools

# Input and output file paths
input_excel_file = "/Users/pavanbandaru/Downloads/cricket-squad-selection/Copy of Final_dataset_updated(1).xlsx"
output_excel_file = "/Users/pavanbandaru/Downloads/cricket-squad-selection/Output_squads_final.xlsx"

# Read all sheets from the Excel file into a dictionary {sheet_name: DataFrame}
sheets_dict = pd.read_excel(input_excel_file, sheet_name=None)

# Dictionary to hold output DataFrames for each sheet
output_dfs = {}

# Process each sheet individually
for sheet_name, df in sheets_dict.items():
    # Calculate score for each player: Score = 0.7 * Form + 0.3 * Consistency
    df['Score'] = 0.7 * df['Form'] + 0.3 * df['Consistency']
    
    # Define positions 1 to 11
    positions = range(1, 12)
    grouped = {}
    missing_position = False
    for pos in positions:
        players_at_pos = df[df['Position'] == pos].to_dict('records')
        if not players_at_pos:
            missing_position = True
            break
        grouped[pos] = players_at_pos
    
    # If any required position is missing, record a message and continue to next sheet.
    if missing_position:
        output_dfs[sheet_name] = pd.DataFrame({
            "Message": [f"Missing players for some positions. Cannot form a complete squad in sheet '{sheet_name}'."]
        })
        continue
    
    # Generate all possible squad combinations (one player per position)
    all_squads = list(itertools.product(*(grouped[pos] for pos in positions)))
    
    # Filter squads based on constraints:
    # - Exactly 4 foreign players (Nationality == "Foreginer")
    # - At least one wicketkeeper (i.e., 'WK' in the "Type" column)
    valid_squads = []
    for squad in all_squads:
        foreign_count = sum(1 for player in squad if player['Nationality'].strip().lower() == 'foreginer')
        wk_count = sum(1 for player in squad if 'WK' in player['Type'])
        if foreign_count == 4 and wk_count >= 1:
            valid_squads.append(squad)
            
    if not valid_squads:
        output_dfs[sheet_name] = pd.DataFrame({
            "Message": [f"No valid squads found meeting criteria in sheet '{sheet_name}'."]
        })
        continue

    # Sort valid squads by total squad score in descending order and select the top 5 squads.
    valid_squads_sorted = sorted(valid_squads,
                                 key=lambda squad: sum(player['Score'] for player in squad),
                                 reverse=True)
    top_squads = valid_squads_sorted[:5]
    
    # Prepare a list of rows containing squad and player details
    rows = []
    for squad_idx, squad in enumerate(top_squads, start=1):
        squad_total_score = sum(player['Score'] for player in squad)
        indian_count = sum(1 for player in squad if player['Nationality'].strip().lower() == 'indian')
        foreign_count = sum(1 for player in squad if player['Nationality'].strip().lower() == 'foreginer')
        # Sort players by their position for clarity
        for player in sorted(squad, key=lambda p: p['Position']):
            row = {
                'Squad_Number': squad_idx,
                'Squad_Total_Score': squad_total_score,
                'Position': player['Position'],
                'Player': player['Player'],
                'Form': player['Form'],
                'Consistency': player['Consistency'],
                'Player_Score': player['Score'],
                'Type': player['Type'],
                'Bowler_Type': player['Bowler_Type'],
                'Nationality': player['Nationality'],
                'Indian_Count': indian_count,
                'Foreigner_Count': foreign_count
            }
            rows.append(row)
    
    # Convert rows into a DataFrame and sort by both Squad_Number and Position
    out_df = pd.DataFrame(rows)
    out_df.sort_values(["Squad_Number", "Position"], inplace=True)
    output_dfs[sheet_name] = out_df

# Write all output DataFrames to a new Excel file with each sheet retaining its own data.
# Also, apply a unique background color for each squad group if the "Squad_Number" column exists.
with pd.ExcelWriter(output_excel_file, engine='xlsxwriter') as writer:
    # Define a list of colors for squads (colors will repeat if more than the list length)
    squad_colors = ['#FFC7CE', '#C6EFCE', '#FFEB9C', '#BDD7EE', '#D9D2E9', '#FCE4D6', '#E2EFDA', '#D9E1F2']
    
    for sheet, out_df in output_dfs.items():
        out_df.to_excel(writer, sheet_name=sheet, index=False)
        workbook = writer.book
        worksheet = writer.sheets[sheet]
        
        # Only apply formatting if "Squad_Number" exists
        if "Squad_Number" in out_df.columns:
            for squad_num, group in out_df.groupby('Squad_Number'):
                color = squad_colors[(int(squad_num) - 1) % len(squad_colors)]
                cell_format = workbook.add_format({'bg_color': color})
                # Apply the format to each row in this group
                for df_index in group.index:
                    excel_row = df_index + 1  # Adjust for header row
                    worksheet.set_row(excel_row, None, cell_format)

print(f"Output with colored squads written to {output_excel_file}")
# Out:
# Output with colored squads written to /Users/pavanbandaru/Downloads/cricket-squad-selection/Output_squads_final.xlsx

# %% [markdown]
# ## Final squad code for consistency alone

# %%
import pandas as pd
import itertools

# Specify the Excel file path and sheet name directly
excel_file_path = "/Users/pavanbandaru/Downloads/cricket-squad-selection/ipl_correct_one.xlsx"
sheet_name = "RCB" 

# Read the Excel file and load the specified sheet into a DataFrame
df = pd.read_excel(excel_file_path, sheet_name=sheet_name)

# Calculate score for each player: Score = 0.7 * Form + 0.3 * Consistency
df['Score'] = 0.0 * df['Form'] + 1 * df['Consistency']

# Optional: Display players with calculated scores
print("Players with calculated scores:")
print(df[['Player', 'Position', 'Form', 'Consistency', 'Score', 'Type', 'Nationality', 'Bowler_Type']])
print("\n")

# Group players by Position (assuming positions 1 to 11)
positions = range(1, 12)
grouped = {pos: df[df['Position'] == pos].to_dict('records')
           for pos in positions if not df[df['Position'] == pos].empty}

# Display available players per position for verification
for pos in positions:
    count = len(grouped[pos]) if pos in grouped else 0
    print(f"Position {pos}: {count} player(s)")
print("\n")

# Generate all possible squad combinations (one player per position)
all_squads = list(itertools.product(*(grouped[pos] for pos in positions)))
print("Total possible squads (before applying constraints):", len(all_squads))
print("\n")

# Filter squads to meet the constraints:
# - Exactly 4 foreign players (Nationality == "Foreginer")
# - At least one wicketkeeper (i.e. 'WK' appears in the "Type" column)
valid_squads = []
for squad in all_squads:
    foreign_count = sum(1 for player in squad if player['Nationality'].strip().lower() == 'foreginer')
    wk_count = sum(1 for player in squad if 'WK' in player['Type'])
    if foreign_count == 4 and wk_count >= 1:
        valid_squads.append(squad)

print("Total valid squads (with exactly 4 foreign players and at least 1 wicketkeeper):", len(valid_squads))
print("\n")

# Sort valid squads by total squad score in descending order.
valid_squads_sorted = sorted(valid_squads,
                             key=lambda squad: sum(player['Score'] for player in squad),
                             reverse=True)

# Select top 5 squads with the highest total score.
top_squads = valid_squads_sorted[:5]

if not top_squads:
    print("No valid squads found meeting all criteria.")
else:
    # Print the top 5 squads with squad details and counts of Indian/Foreigner players.
    print("Top 5 Squads (by total squad score):\n")
    for idx, squad in enumerate(top_squads, start=1):
        squad_score = sum(player['Score'] for player in squad)
        # Count nationality occurrences
        indian_count = sum(1 for player in squad if player['Nationality'].strip().lower() == 'indian')
        foreign_count = sum(1 for player in squad if player['Nationality'].strip().lower() == 'foreginer')
        
        print(f"Squad {idx} (Total Score: {squad_score:.2f}):")
        for player in sorted(squad, key=lambda p: p['Position']):
            print(f"  Position {player['Position']}: {player['Player']} - Score: {player['Score']:.2f} | Type: {player['Type']} | Bowler Type: {player['Bowler_Type']} | Nationality: {player['Nationality']}")
        print(f"  --> Count: Indian = {indian_count}, Foreginer = {foreign_count}\n")
# Out:
# Players with calculated scores:
#             Player  Position        Form  Consistency        Score    Type  \
# 0          PD Salt         1   97.855912   121.416700   121.416700  BAT,WK
# 1          V Kohli         2  133.657600  1087.267000  1087.267000     BAT
# 2       SS Chikara         2    9.550107     8.686780     8.686780     BAT
# 3       RM Patidar         3   88.992590   138.074400   138.074400     BAT
# 4       D Padikkal         3   19.237172   120.817100   120.817100     BAT
# 5   LS Livingstone         4   21.392604    77.716706    77.716706      AR
# 6        JM Sharma         5   51.119763   124.918600   124.918600  BAT,WK
# 7      MS Bhandage         6    7.693454    16.143654    16.143654      AR
# 8         TH David         6   65.436768   120.975700   120.975700     BAT
# 9        KH Pandya         7   22.823990   145.633904   145.633904      AR
# 10      R Shepherd         7   22.694281    20.728633    20.728633      AR
# 11   Swapnil Singh         8   20.610524    12.807622    12.807622      AR
# 12         B Kumar         8   -3.866449    43.731870    43.731870    BOWL
# 13    Rasikh Salam         9   -2.521690    -6.720070    -6.720070    BOWL
# 14      N Thushara         9  -12.951069   -15.775040   -15.775040    BOWL
# 15      Yash Dayal        10   -0.284155    -0.394590    -0.394590    BOWL
# 16         L Ngidi        10   -3.141651     2.160578     2.160578    BOWL
# 17   Suyash Sharma         8   -3.541651    12.807622    12.807622    BOWL
# 18    JR Hazlewood        11   -3.508667     3.830991     3.830991    BOWL
# 19    Mohit Rathee        11  -15.119889   -22.633300   -22.633300    BOWL
#
#    Nationality Bowler_Type
# 0    Foreginer         NaN
# 1       Indian         NaN
# 2       Indian         NaN
# 3       Indian         NaN
# 4       Indian         NaN
# 5    Foreginer        Spin
# 6       Indian         NaN
# 7       Indian        Pace
# 8    Foreginer         NaN
# 9       Indian        Spin
# 10   Foreginer        Pace
# 11      Indian        Spin
# 12      Indian        Pace
# 13      Indian        Pace
# 14   Foreginer        Pace
# 15      Indian        Pace
# 16   Foreginer        Pace
# 17      Indian        Spin
# 18   Foreginer        Pace
# 19      Indian        Spin
#
#
# Position 1: 1 player(s)
# Position 2: 2 player(s)
# Position 3: 2 player(s)
# Position 4: 1 player(s)
# Position 5: 1 player(s)
# Position 6: 2 player(s)
# Position 7: 2 player(s)
# Position 8: 3 player(s)
# Position 9: 2 player(s)
# Position 10: 2 player(s)
# Position 11: 2 player(s)
#
#
# Total possible squads (before applying constraints): 384
#
#
# Total valid squads (with exactly 4 foreign players and at least 1 wicketkeeper): 120
#
#
# Top 5 Squads (by total squad score):
#
# Squad 1 (Total Score: 1856.45):
#   Position 1: PD Salt - Score: 121.42 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 1087.27 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 138.07 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: LS Livingstone - Score: 77.72 | Type: AR | Bowler Type: Spin | Nationality: Foreginer
#   Position 5: JM Sharma - Score: 124.92 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 120.98 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 145.63 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: B Kumar - Score: 43.73 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 9: Rasikh Salam - Score: -6.72 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 10: Yash Dayal - Score: -0.39 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: JR Hazlewood - Score: 3.83 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 2 (Total Score: 1839.19):
#   Position 1: PD Salt - Score: 121.42 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 1087.27 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: D Padikkal - Score: 120.82 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: LS Livingstone - Score: 77.72 | Type: AR | Bowler Type: Spin | Nationality: Foreginer
#   Position 5: JM Sharma - Score: 124.92 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 120.98 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 145.63 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: B Kumar - Score: 43.73 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 9: Rasikh Salam - Score: -6.72 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 10: Yash Dayal - Score: -0.39 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: JR Hazlewood - Score: 3.83 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 3 (Total Score: 1832.54):
#   Position 1: PD Salt - Score: 121.42 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 1087.27 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 138.07 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: LS Livingstone - Score: 77.72 | Type: AR | Bowler Type: Spin | Nationality: Foreginer
#   Position 5: JM Sharma - Score: 124.92 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 120.98 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 145.63 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: B Kumar - Score: 43.73 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 9: Rasikh Salam - Score: -6.72 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 10: L Ngidi - Score: 2.16 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   Position 11: Mohit Rathee - Score: -22.63 | Type: BOWL | Bowler Type: Spin | Nationality: Indian
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 4 (Total Score: 1825.53):
#   Position 1: PD Salt - Score: 121.42 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 1087.27 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 138.07 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: LS Livingstone - Score: 77.72 | Type: AR | Bowler Type: Spin | Nationality: Foreginer
#   Position 5: JM Sharma - Score: 124.92 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 120.98 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 145.63 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: Swapnil Singh - Score: 12.81 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 9: Rasikh Salam - Score: -6.72 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 10: Yash Dayal - Score: -0.39 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: JR Hazlewood - Score: 3.83 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 5 (Total Score: 1825.53):
#   Position 1: PD Salt - Score: 121.42 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 1087.27 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 138.07 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: LS Livingstone - Score: 77.72 | Type: AR | Bowler Type: Spin | Nationality: Foreginer
#   Position 5: JM Sharma - Score: 124.92 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 120.98 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 145.63 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: Suyash Sharma - Score: 12.81 | Type: BOWL | Bowler Type: Spin | Nationality: Indian
#   Position 9: Rasikh Salam - Score: -6.72 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 10: Yash Dayal - Score: -0.39 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: JR Hazlewood - Score: 3.83 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4

# %% [markdown]
# ## Final squad code for form alone

# %%
import pandas as pd
import itertools

# Specify the Excel file path and sheet name directly
excel_file_path = "/Users/pavanbandaru/Downloads/cricket-squad-selection/ipl_correct_one.xlsx"
sheet_name = "RCB" 

# Read the Excel file and load the specified sheet into a DataFrame
df = pd.read_excel(excel_file_path, sheet_name=sheet_name)

# Calculate score for each player: Score = 0.7 * Form + 0.3 * Consistency
df['Score'] = 1 * df['Form'] + 0.0 * df['Consistency']

# Optional: Display players with calculated scores
print("Players with calculated scores:")
print(df[['Player', 'Position', 'Form', 'Consistency', 'Score', 'Type', 'Nationality', 'Bowler_Type']])
print("\n")

# Group players by Position (assuming positions 1 to 11)
positions = range(1, 12)
grouped = {pos: df[df['Position'] == pos].to_dict('records')
           for pos in positions if not df[df['Position'] == pos].empty}

# Display available players per position for verification
for pos in positions:
    count = len(grouped[pos]) if pos in grouped else 0
    print(f"Position {pos}: {count} player(s)")
print("\n")

# Generate all possible squad combinations (one player per position)
all_squads = list(itertools.product(*(grouped[pos] for pos in positions)))
print("Total possible squads (before applying constraints):", len(all_squads))
print("\n")

# Filter squads to meet the constraints:
# - Exactly 4 foreign players (Nationality == "Foreginer")
# - At least one wicketkeeper (i.e. 'WK' appears in the "Type" column)
valid_squads = []
for squad in all_squads:
    foreign_count = sum(1 for player in squad if player['Nationality'].strip().lower() == 'foreginer')
    wk_count = sum(1 for player in squad if 'WK' in player['Type'])
    if foreign_count == 4 and wk_count >= 1:
        valid_squads.append(squad)

print("Total valid squads (with exactly 4 foreign players and at least 1 wicketkeeper):", len(valid_squads))
print("\n")

# Sort valid squads by total squad score in descending order.
valid_squads_sorted = sorted(valid_squads,
                             key=lambda squad: sum(player['Score'] for player in squad),
                             reverse=True)

# Select top 5 squads with the highest total score.
top_squads = valid_squads_sorted[:5]

if not top_squads:
    print("No valid squads found meeting all criteria.")
else:
    # Print the top 5 squads with squad details and counts of Indian/Foreigner players.
    print("Top 5 Squads (by total squad score):\n")
    for idx, squad in enumerate(top_squads, start=1):
        squad_score = sum(player['Score'] for player in squad)
        # Count nationality occurrences
        indian_count = sum(1 for player in squad if player['Nationality'].strip().lower() == 'indian')
        foreign_count = sum(1 for player in squad if player['Nationality'].strip().lower() == 'foreginer')
        
        print(f"Squad {idx} (Total Score: {squad_score:.2f}):")
        for player in sorted(squad, key=lambda p: p['Position']):
            print(f"  Position {player['Position']}: {player['Player']} - Score: {player['Score']:.2f} | Type: {player['Type']} | Bowler Type: {player['Bowler_Type']} | Nationality: {player['Nationality']}")
        print(f"  --> Count: Indian = {indian_count}, Foreginer = {foreign_count}\n")
# Out:
# Players with calculated scores:
#             Player  Position        Form  Consistency       Score    Type  \
# 0          PD Salt         1   97.855912   121.416700   97.855912  BAT,WK
# 1          V Kohli         2  133.657600  1087.267000  133.657600     BAT
# 2       SS Chikara         2    9.550107     8.686780    9.550107     BAT
# 3       RM Patidar         3   88.992590   138.074400   88.992590     BAT
# 4       D Padikkal         3   19.237172   120.817100   19.237172     BAT
# 5   LS Livingstone         4   21.392604    77.716706   21.392604      AR
# 6        JM Sharma         5   51.119763   124.918600   51.119763  BAT,WK
# 7      MS Bhandage         6    7.693454    16.143654    7.693454      AR
# 8         TH David         6   65.436768   120.975700   65.436768     BAT
# 9        KH Pandya         7   22.823990   145.633904   22.823990      AR
# 10      R Shepherd         7   22.694281    20.728633   22.694281      AR
# 11   Swapnil Singh         8   20.610524    12.807622   20.610524      AR
# 12         B Kumar         8   -3.866449    43.731870   -3.866449    BOWL
# 13    Rasikh Salam         9   -2.521690    -6.720070   -2.521690    BOWL
# 14      N Thushara         9  -12.951069   -15.775040  -12.951069    BOWL
# 15      Yash Dayal        10   -0.284155    -0.394590   -0.284155    BOWL
# 16         L Ngidi        10   -3.141651     2.160578   -3.141651    BOWL
# 17   Suyash Sharma         8   -3.541651    12.807622   -3.541651    BOWL
# 18    JR Hazlewood        11   -3.508667     3.830991   -3.508667    BOWL
# 19    Mohit Rathee        11  -15.119889   -22.633300  -15.119889    BOWL
#
#    Nationality Bowler_Type
# 0    Foreginer         NaN
# 1       Indian         NaN
# 2       Indian         NaN
# 3       Indian         NaN
# 4       Indian         NaN
# 5    Foreginer        Spin
# 6       Indian         NaN
# 7       Indian        Pace
# 8    Foreginer         NaN
# 9       Indian        Spin
# 10   Foreginer        Pace
# 11      Indian        Spin
# 12      Indian        Pace
# 13      Indian        Pace
# 14   Foreginer        Pace
# 15      Indian        Pace
# 16   Foreginer        Pace
# 17      Indian        Spin
# 18   Foreginer        Pace
# 19      Indian        Spin
#
#
# Position 1: 1 player(s)
# Position 2: 2 player(s)
# Position 3: 2 player(s)
# Position 4: 1 player(s)
# Position 5: 1 player(s)
# Position 6: 2 player(s)
# Position 7: 2 player(s)
# Position 8: 3 player(s)
# Position 9: 2 player(s)
# Position 10: 2 player(s)
# Position 11: 2 player(s)
#
#
# Total possible squads (before applying constraints): 384
#
#
# Total valid squads (with exactly 4 foreign players and at least 1 wicketkeeper): 120
#
#
# Top 5 Squads (by total squad score):
#
# Squad 1 (Total Score: 495.58):
#   Position 1: PD Salt - Score: 97.86 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 133.66 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 88.99 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: LS Livingstone - Score: 21.39 | Type: AR | Bowler Type: Spin | Nationality: Foreginer
#   Position 5: JM Sharma - Score: 51.12 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 65.44 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 22.82 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: Swapnil Singh - Score: 20.61 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 9: Rasikh Salam - Score: -2.52 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 10: Yash Dayal - Score: -0.28 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: JR Hazlewood - Score: -3.51 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 2 (Total Score: 483.83):
#   Position 1: PD Salt - Score: 97.86 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 133.66 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 88.99 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: LS Livingstone - Score: 21.39 | Type: AR | Bowler Type: Spin | Nationality: Foreginer
#   Position 5: JM Sharma - Score: 51.12 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 65.44 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: R Shepherd - Score: 22.69 | Type: AR | Bowler Type: Pace | Nationality: Foreginer
#   Position 8: Swapnil Singh - Score: 20.61 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 9: Rasikh Salam - Score: -2.52 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 10: Yash Dayal - Score: -0.28 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: Mohit Rathee - Score: -15.12 | Type: BOWL | Bowler Type: Spin | Nationality: Indian
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 3 (Total Score: 481.11):
#   Position 1: PD Salt - Score: 97.86 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 133.66 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 88.99 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: LS Livingstone - Score: 21.39 | Type: AR | Bowler Type: Spin | Nationality: Foreginer
#   Position 5: JM Sharma - Score: 51.12 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 65.44 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 22.82 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: Swapnil Singh - Score: 20.61 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 9: Rasikh Salam - Score: -2.52 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 10: L Ngidi - Score: -3.14 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   Position 11: Mohit Rathee - Score: -15.12 | Type: BOWL | Bowler Type: Spin | Nationality: Indian
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 4 (Total Score: 473.53):
#   Position 1: PD Salt - Score: 97.86 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 133.66 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 88.99 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: LS Livingstone - Score: 21.39 | Type: AR | Bowler Type: Spin | Nationality: Foreginer
#   Position 5: JM Sharma - Score: 51.12 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 65.44 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 22.82 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: Swapnil Singh - Score: 20.61 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 9: N Thushara - Score: -12.95 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   Position 10: Yash Dayal - Score: -0.28 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: Mohit Rathee - Score: -15.12 | Type: BOWL | Bowler Type: Spin | Nationality: Indian
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 5 (Total Score: 471.42):
#   Position 1: PD Salt - Score: 97.86 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 133.66 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 88.99 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: LS Livingstone - Score: 21.39 | Type: AR | Bowler Type: Spin | Nationality: Foreginer
#   Position 5: JM Sharma - Score: 51.12 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 65.44 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 22.82 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: Suyash Sharma - Score: -3.54 | Type: BOWL | Bowler Type: Spin | Nationality: Indian
#   Position 9: Rasikh Salam - Score: -2.52 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 10: Yash Dayal - Score: -0.28 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: JR Hazlewood - Score: -3.51 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4

# %% [markdown]
# ## Final squad code for both consistency and form

# %%
import pandas as pd
import itertools

excel_file_path = "/Users/pavanbandaru/Downloads/cricket-squad-selection/ipl_correct_one.xlsx"
sheet_name = "RCB"

df = pd.read_excel(excel_file_path, sheet_name=sheet_name)

df['Score'] = 0.7 * df['Form'] + 0.3 * df['Consistency']

print("Players with calculated scores:")
print(df[['Player', 'Position', 'Form', 'Consistency', 'Score', 'Type', 'Nationality', 'Bowler_Type']])
print("\n")

positions = range(1, 12)
grouped = {pos: df[df['Position'] == pos].to_dict('records')
           for pos in positions if not df[df['Position'] == pos].empty}

for pos in positions:
    count = len(grouped[pos]) if pos in grouped else 0
    print(f"Position {pos}: {count} player(s)")
print("\n")

all_squads = list(itertools.product(*(grouped[pos] for pos in positions)))
print("Total possible squads (before applying constraints):", len(all_squads))
print("\n")

valid_squads = []
for squad in all_squads:
    foreign_count = sum(1 for player in squad if player['Nationality'].strip().lower() == 'foreginer')
    wk_count = sum(1 for player in squad if 'WK' in player['Type'])
    if foreign_count == 4 and wk_count >= 1:
        valid_squads.append(squad)

print("Total valid squads (with exactly 4 foreign players and at least 1 wicketkeeper):", len(valid_squads))
print("\n")

valid_squads_sorted = sorted(valid_squads,
                             key=lambda squad: sum(player['Score'] for player in squad),
                             reverse=True)

top_squads = valid_squads_sorted[:5]

if not top_squads:
    print("No valid squads found meeting all criteria.")
else:
    print("Top 5 Squads (by total squad score):\n")
    for idx, squad in enumerate(top_squads, start=1):
        squad_score = sum(player['Score'] for player in squad)
        indian_count = sum(1 for player in squad if player['Nationality'].strip().lower() == 'indian')
        foreign_count = sum(1 for player in squad if player['Nationality'].strip().lower() == 'foreginer')
        
        print(f"Squad {idx} (Total Score: {squad_score:.2f}):")
        for player in sorted(squad, key=lambda p: p['Position']):
            print(f"  Position {player['Position']}: {player['Player']} - Score: {player['Score']:.2f} | Type: {player['Type']} | Bowler Type: {player['Bowler_Type']} | Nationality: {player['Nationality']}")
        print(f"  --> Count: Indian = {indian_count}, Foreginer = {foreign_count}\n")
# Out:
# Players with calculated scores:
#             Player  Position        Form  Consistency       Score    Type  \
# 0          PD Salt         1   97.855912   121.416700  104.924148  BAT,WK
# 1          V Kohli         2  133.657600  1087.267000  419.740420     BAT
# 2       SS Chikara         2    9.550107     8.686780    9.291109     BAT
# 3       RM Patidar         3   88.992590   138.074400  103.717133     BAT
# 4       D Padikkal         3   19.237172   120.817100   49.711151     BAT
# 5   LS Livingstone         4   21.392604    77.716706   38.289834      AR
# 6        JM Sharma         5   51.119763   124.918600   73.259414  BAT,WK
# 7      MS Bhandage         6    7.693454    16.143654   10.228514      AR
# 8         TH David         6   65.436768   120.975700   82.098447     BAT
# 9        KH Pandya         7   22.823990   145.633904   59.666964      AR
# 10      R Shepherd         7   22.694281    20.728633   22.104586      AR
# 11   Swapnil Singh         8   20.610524    12.807622   18.269653      AR
# 12         B Kumar         8   -3.866449    43.731870   10.413047    BOWL
# 13    Rasikh Salam         9   -2.521690    -6.720070   -3.781204    BOWL
# 14      N Thushara         9  -12.951069   -15.775040  -13.798260    BOWL
# 15      Yash Dayal        10   -0.284155    -0.394590   -0.317286    BOWL
# 16         L Ngidi        10   -3.141651     2.160578   -1.550982    BOWL
# 17   Suyash Sharma         8   -3.541651    12.807622    1.363131    BOWL
# 18    JR Hazlewood        11   -3.508667     3.830991   -1.306770    BOWL
# 19    Mohit Rathee        11  -15.119889   -22.633300  -17.373913    BOWL
#
#    Nationality Bowler_Type
# 0    Foreginer         NaN
# 1       Indian         NaN
# 2       Indian         NaN
# 3       Indian         NaN
# 4       Indian         NaN
# 5    Foreginer        Spin
# 6       Indian         NaN
# 7       Indian        Pace
# 8    Foreginer         NaN
# 9       Indian        Spin
# 10   Foreginer        Pace
# 11      Indian        Spin
# 12      Indian        Pace
# 13      Indian        Pace
# 14   Foreginer        Pace
# 15      Indian        Pace
# 16   Foreginer        Pace
# 17      Indian        Spin
# 18   Foreginer        Pace
# 19      Indian        Spin
#
#
# Position 1: 1 player(s)
# Position 2: 2 player(s)
# Position 3: 2 player(s)
# Position 4: 1 player(s)
# Position 5: 1 player(s)
# Position 6: 2 player(s)
# Position 7: 2 player(s)
# Position 8: 3 player(s)
# Position 9: 2 player(s)
# Position 10: 2 player(s)
# Position 11: 2 player(s)
#
#
# Total possible squads (before applying constraints): 384
#
#
# Total valid squads (with exactly 4 foreign players and at least 1 wicketkeeper): 120
#
#
# Top 5 Squads (by total squad score):
#
# Squad 1 (Total Score: 894.56):
#   Position 1: PD Salt - Score: 104.92 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 419.74 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 103.72 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: LS Livingstone - Score: 38.29 | Type: AR | Bowler Type: Spin | Nationality: Foreginer
#   Position 5: JM Sharma - Score: 73.26 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 82.10 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 59.67 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: Swapnil Singh - Score: 18.27 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 9: Rasikh Salam - Score: -3.78 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 10: Yash Dayal - Score: -0.32 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: JR Hazlewood - Score: -1.31 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 2 (Total Score: 886.70):
#   Position 1: PD Salt - Score: 104.92 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 419.74 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 103.72 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: LS Livingstone - Score: 38.29 | Type: AR | Bowler Type: Spin | Nationality: Foreginer
#   Position 5: JM Sharma - Score: 73.26 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 82.10 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 59.67 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: B Kumar - Score: 10.41 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 9: Rasikh Salam - Score: -3.78 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 10: Yash Dayal - Score: -0.32 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: JR Hazlewood - Score: -1.31 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 3 (Total Score: 877.65):
#   Position 1: PD Salt - Score: 104.92 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 419.74 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 103.72 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: LS Livingstone - Score: 38.29 | Type: AR | Bowler Type: Spin | Nationality: Foreginer
#   Position 5: JM Sharma - Score: 73.26 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 82.10 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 59.67 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: Suyash Sharma - Score: 1.36 | Type: BOWL | Bowler Type: Spin | Nationality: Indian
#   Position 9: Rasikh Salam - Score: -3.78 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 10: Yash Dayal - Score: -0.32 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: JR Hazlewood - Score: -1.31 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 4 (Total Score: 877.26):
#   Position 1: PD Salt - Score: 104.92 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 419.74 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 103.72 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: LS Livingstone - Score: 38.29 | Type: AR | Bowler Type: Spin | Nationality: Foreginer
#   Position 5: JM Sharma - Score: 73.26 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 82.10 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 59.67 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: Swapnil Singh - Score: 18.27 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 9: Rasikh Salam - Score: -3.78 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 10: L Ngidi - Score: -1.55 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   Position 11: Mohit Rathee - Score: -17.37 | Type: BOWL | Bowler Type: Spin | Nationality: Indian
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 5 (Total Score: 869.40):
#   Position 1: PD Salt - Score: 104.92 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 419.74 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 103.72 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: LS Livingstone - Score: 38.29 | Type: AR | Bowler Type: Spin | Nationality: Foreginer
#   Position 5: JM Sharma - Score: 73.26 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 82.10 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 59.67 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: B Kumar - Score: 10.41 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 9: Rasikh Salam - Score: -3.78 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 10: L Ngidi - Score: -1.55 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   Position 11: Mohit Rathee - Score: -17.37 | Type: BOWL | Bowler Type: Spin | Nationality: Indian
#   --> Count: Indian = 7, Foreginer = 4

# %% [markdown]
# ## Final squad code for both consistency and form using AHP

# %%
import pandas as pd
import itertools

# Specify the Excel file path and sheet name directly
excel_file_path = "/Users/pavanbandaru/Downloads/cricket-squad-selection/ipl_correct_one copy.xlsx"
sheet_name = "RCB" 

# Read the Excel file and load the specified sheet into a DataFrame
df = pd.read_excel(excel_file_path, sheet_name=sheet_name)

# Calculate score for each player: Score = 0.7 * Form_AHP + 0.3 * Consistency_AHP
df['Score'] = 0.7 * df['Form_AHP'] + 0.3 * df['Consistency_AHP']

# Optional: Display players with calculated scores
print("Players with calculated scores:")
print(df[['Player', 'Position', 'Form_AHP', 'Consistency_AHP', 'Score', 'Type', 'Nationality', 'Bowler_Type']])
print("\n")

# Group players by Position (assuming positions 1 to 11)
positions = range(1, 12)
grouped = {pos: df[df['Position'] == pos].to_dict('records')
           for pos in positions if not df[df['Position'] == pos].empty}

# Display available players per position for verification
for pos in positions:
    count = len(grouped[pos]) if pos in grouped else 0
    print(f"Position {pos}: {count} player(s)")
print("\n")

# Generate all possible squad combinations (one player per position)
all_squads = list(itertools.product(*(grouped[pos] for pos in positions)))
print("Total possible squads (before applying constraints):", len(all_squads))
print("\n")

# Filter squads to meet the constraints:
# - Exactly 4 foreign players (Nationality == "Foreginer")
# - At least one wicketkeeper (i.e. 'WK' appears in the "Type" column)
valid_squads = []
for squad in all_squads:
    foreign_count = sum(1 for player in squad if player['Nationality'].strip().lower() == 'foreginer')
    wk_count = sum(1 for player in squad if 'WK' in player['Type'])
    if foreign_count == 4 and wk_count >= 1:
        valid_squads.append(squad)

print("Total valid squads (with exactly 4 foreign players and at least 1 wicketkeeper):", len(valid_squads))
print("\n")

# Sort valid squads by total squad score in descending order.
valid_squads_sorted = sorted(valid_squads,
                             key=lambda squad: sum(player['Score'] for player in squad),
                             reverse=True)

# Select top 5 squads with the highest total score.
top_squads = valid_squads_sorted[:5]

if not top_squads:
    print("No valid squads found meeting all criteria.")
else:
    # Print the top 5 squads with squad details and counts of Indian/Foreigner players.
    print("Top 5 Squads (by total squad score):\n")
    for idx, squad in enumerate(top_squads, start=1):
        squad_score = sum(player['Score'] for player in squad)
        # Count nationality occurrences
        indian_count = sum(1 for player in squad if player['Nationality'].strip().lower() == 'indian')
        foreign_count = sum(1 for player in squad if player['Nationality'].strip().lower() == 'foreginer')
        
        print(f"Squad {idx} (Total Score: {squad_score:.2f}):")
        for player in sorted(squad, key=lambda p: p['Position']):
            print(f"  Position {player['Position']}: {player['Player']} - Score: {player['Score']:.2f} | Type: {player['Type']} | Bowler Type: {player['Bowler_Type']} | Nationality: {player['Nationality']}")
        print(f"  --> Count: Indian = {indian_count}, Foreginer = {foreign_count}\n")
# Out:
# Players with calculated scores:
#             Player  Position   Form_AHP  Consistency_AHP       Score    Type  \
# 0          PD Salt         1  56.787230        67.052939   59.866943  BAT,WK
# 1          V Kohli         2  70.983470       452.085246  185.314003     BAT
# 2       SS Chikara         2  10.556400        10.556397   10.556399     BAT
# 3       RM Patidar         3  52.286320        71.323661   57.997522     BAT
# 4       D Padikkal         4  16.040340       104.713407   42.642260     BAT
# 5   LS Livingstone         4  15.777390       101.354033   41.450383      AR
# 6        JM Sharma         5  32.600720        65.363815   42.429649  BAT,WK
# 7      MS Bhandage         6   9.752964        16.925261   11.904653      AR
# 8         TH David         6  41.507540        66.978910   49.148951     BAT
# 9        KH Pandya         7  17.326540        71.179393   33.482396      AR
# 10      R Shepherd         7  22.528510        18.194121   21.228193      AR
# 11   Swapnil Singh         8  15.721150        10.540120   14.166841      AR
# 12         B Kumar         8  20.620832        39.300988   26.224879    BOWL
# 13    Rasikh Salam         9  -3.374755        -4.556714   -3.729343    BOWL
# 14      N Thushara         9  -3.159281        -3.859281   -3.369281    BOWL
# 15      Yash Dayal        10  -1.862285         0.855878   -1.046836    BOWL
# 16         L Ngidi        10  -3.500917         2.748738   -1.626020    BOWL
# 17   Suyash Sharma        10 -16.900000        -4.062190  -13.048657    BOWL
# 18    JR Hazlewood        11  -3.831420         4.310629   -1.388805    BOWL
# 19    Mohit Rathee        11 -17.081340       -17.081343  -17.081341    BOWL
#
#    Nationality Bowler_Type
# 0    Foreginer         NaN
# 1       Indian         NaN
# 2       Indian         NaN
# 3       Indian         NaN
# 4       Indian         NaN
# 5    Foreginer        Spin
# 6       Indian         NaN
# 7       Indian        Pace
# 8    Foreginer         NaN
# 9       Indian        Spin
# 10   Foreginer        Pace
# 11      Indian        Spin
# 12      Indian        Pace
# 13      Indian        Pace
# 14   Foreginer        Pace
# 15      Indian        Pace
# 16   Foreginer        Pace
# 17      Indian        Spin
# 18   Foreginer        Pace
# 19      Indian        Spin
#
#
# Position 1: 1 player(s)
# Position 2: 2 player(s)
# Position 3: 1 player(s)
# Position 4: 2 player(s)
# Position 5: 1 player(s)
# Position 6: 2 player(s)
# Position 7: 2 player(s)
# Position 8: 2 player(s)
# Position 9: 2 player(s)
# Position 10: 3 player(s)
# Position 11: 2 player(s)
#
#
# Total possible squads (before applying constraints): 384
#
#
# Total valid squads (with exactly 4 foreign players and at least 1 wicketkeeper): 120
#
#
# Top 5 Squads (by total squad score):
#
# Squad 1 (Total Score: 491.30):
#   Position 1: PD Salt - Score: 59.87 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 185.31 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 58.00 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: D Padikkal - Score: 42.64 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 5: JM Sharma - Score: 42.43 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 49.15 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 33.48 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: B Kumar - Score: 26.22 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 9: N Thushara - Score: -3.37 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   Position 10: Yash Dayal - Score: -1.05 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: JR Hazlewood - Score: -1.39 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 2 (Total Score: 490.36):
#   Position 1: PD Salt - Score: 59.87 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 185.31 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 58.00 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: D Padikkal - Score: 42.64 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 5: JM Sharma - Score: 42.43 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 49.15 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 33.48 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: B Kumar - Score: 26.22 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 9: Rasikh Salam - Score: -3.73 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 10: L Ngidi - Score: -1.63 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   Position 11: JR Hazlewood - Score: -1.39 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 3 (Total Score: 489.75):
#   Position 1: PD Salt - Score: 59.87 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 185.31 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 58.00 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: LS Livingstone - Score: 41.45 | Type: AR | Bowler Type: Spin | Nationality: Foreginer
#   Position 5: JM Sharma - Score: 42.43 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 49.15 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 33.48 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: B Kumar - Score: 26.22 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 9: Rasikh Salam - Score: -3.73 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 10: Yash Dayal - Score: -1.05 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: JR Hazlewood - Score: -1.39 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 4 (Total Score: 479.30):
#   Position 1: PD Salt - Score: 59.87 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 185.31 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 58.00 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: D Padikkal - Score: 42.64 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 5: JM Sharma - Score: 42.43 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 49.15 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 33.48 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: B Kumar - Score: 26.22 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 9: N Thushara - Score: -3.37 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   Position 10: Suyash Sharma - Score: -13.05 | Type: BOWL | Bowler Type: Spin | Nationality: Indian
#   Position 11: JR Hazlewood - Score: -1.39 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 5 (Total Score: 479.24):
#   Position 1: PD Salt - Score: 59.87 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 185.31 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 58.00 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: D Padikkal - Score: 42.64 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 5: JM Sharma - Score: 42.43 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 49.15 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 33.48 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: Swapnil Singh - Score: 14.17 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 9: N Thushara - Score: -3.37 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   Position 10: Yash Dayal - Score: -1.05 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: JR Hazlewood - Score: -1.39 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4

# %% [markdown]
# ## Final code for Form alone using AHP

# %%
import pandas as pd
import itertools

# Specify the Excel file path and sheet name directly
excel_file_path = "/Users/pavanbandaru/Downloads/cricket-squad-selection/ipl_correct_one copy.xlsx"
sheet_name = "RCB" 

# Read the Excel file and load the specified sheet into a DataFrame
df = pd.read_excel(excel_file_path, sheet_name=sheet_name)

# Calculate score for each player: Score = 0.7 * Form_AHP + 0.3 * Consistency_AHP
df['Score'] = 1 * df['Form_AHP'] + 0 * df['Consistency_AHP']

# Optional: Display players with calculated scores
print("Players with calculated scores:")
print(df[['Player', 'Position', 'Form_AHP', 'Consistency_AHP', 'Score', 'Type', 'Nationality', 'Bowler_Type']])
print("\n")

# Group players by Position (assuming positions 1 to 11)
positions = range(1, 12)
grouped = {pos: df[df['Position'] == pos].to_dict('records')
           for pos in positions if not df[df['Position'] == pos].empty}

# Display available players per position for verification
for pos in positions:
    count = len(grouped[pos]) if pos in grouped else 0
    print(f"Position {pos}: {count} player(s)")
print("\n")

# Generate all possible squad combinations (one player per position)
all_squads = list(itertools.product(*(grouped[pos] for pos in positions)))
print("Total possible squads (before applying constraints):", len(all_squads))
print("\n")

# Filter squads to meet the constraints:
# - Exactly 4 foreign players (Nationality == "Foreginer")
# - At least one wicketkeeper (i.e. 'WK' appears in the "Type" column)
valid_squads = []
for squad in all_squads:
    foreign_count = sum(1 for player in squad if player['Nationality'].strip().lower() == 'foreginer')
    wk_count = sum(1 for player in squad if 'WK' in player['Type'])
    if foreign_count == 4 and wk_count >= 1:
        valid_squads.append(squad)

print("Total valid squads (with exactly 4 foreign players and at least 1 wicketkeeper):", len(valid_squads))
print("\n")

# Sort valid squads by total squad score in descending order.
valid_squads_sorted = sorted(valid_squads,
                             key=lambda squad: sum(player['Score'] for player in squad),
                             reverse=True)

# Select top 5 squads with the highest total score.
top_squads = valid_squads_sorted[:5]

if not top_squads:
    print("No valid squads found meeting all criteria.")
else:
    # Print the top 5 squads with squad details and counts of Indian/Foreigner players.
    print("Top 5 Squads (by total squad score):\n")
    for idx, squad in enumerate(top_squads, start=1):
        squad_score = sum(player['Score'] for player in squad)
        # Count nationality occurrences
        indian_count = sum(1 for player in squad if player['Nationality'].strip().lower() == 'indian')
        foreign_count = sum(1 for player in squad if player['Nationality'].strip().lower() == 'foreginer')
        
        print(f"Squad {idx} (Total Score: {squad_score:.2f}):")
        for player in sorted(squad, key=lambda p: p['Position']):
            print(f"  Position {player['Position']}: {player['Player']} - Score: {player['Score']:.2f} | Type: {player['Type']} | Bowler Type: {player['Bowler_Type']} | Nationality: {player['Nationality']}")
        print(f"  --> Count: Indian = {indian_count}, Foreginer = {foreign_count}\n")
# Out:
# Players with calculated scores:
#             Player  Position   Form_AHP  Consistency_AHP      Score    Type  \
# 0          PD Salt         1  56.787230        67.052939  56.787230  BAT,WK
# 1          V Kohli         2  70.983470       452.085246  70.983470     BAT
# 2       SS Chikara         2  10.556400        10.556397  10.556400     BAT
# 3       RM Patidar         3  52.286320        71.323661  52.286320     BAT
# 4       D Padikkal         4  16.040340       104.713407  16.040340     BAT
# 5   LS Livingstone         4  15.777390       101.354033  15.777390      AR
# 6        JM Sharma         5  32.600720        65.363815  32.600720  BAT,WK
# 7      MS Bhandage         6   9.752964        16.925261   9.752964      AR
# 8         TH David         6  41.507540        66.978910  41.507540     BAT
# 9        KH Pandya         7  17.326540        71.179393  17.326540      AR
# 10      R Shepherd         7  22.528510        18.194121  22.528510      AR
# 11   Swapnil Singh         8  15.721150        10.540120  15.721150      AR
# 12         B Kumar         8  20.620832        39.300988  20.620832    BOWL
# 13    Rasikh Salam         9  -3.374755        -4.556714  -3.374755    BOWL
# 14      N Thushara         9  -3.159281        -3.859281  -3.159281    BOWL
# 15      Yash Dayal        10  -1.862285         0.855878  -1.862285    BOWL
# 16         L Ngidi        10  -3.500917         2.748738  -3.500917    BOWL
# 17   Suyash Sharma        10 -16.900000        -4.062190 -16.900000    BOWL
# 18    JR Hazlewood        11  -3.831420         4.310629  -3.831420    BOWL
# 19    Mohit Rathee        11 -17.081340       -17.081343 -17.081340    BOWL
#
#    Nationality Bowler_Type
# 0    Foreginer         NaN
# 1       Indian         NaN
# 2       Indian         NaN
# 3       Indian         NaN
# 4       Indian         NaN
# 5    Foreginer        Spin
# 6       Indian         NaN
# 7       Indian        Pace
# 8    Foreginer         NaN
# 9       Indian        Spin
# 10   Foreginer        Pace
# 11      Indian        Spin
# 12      Indian        Pace
# 13      Indian        Pace
# 14   Foreginer        Pace
# 15      Indian        Pace
# 16   Foreginer        Pace
# 17      Indian        Spin
# 18   Foreginer        Pace
# 19      Indian        Spin
#
#
# Position 1: 1 player(s)
# Position 2: 2 player(s)
# Position 3: 1 player(s)
# Position 4: 2 player(s)
# Position 5: 1 player(s)
# Position 6: 2 player(s)
# Position 7: 2 player(s)
# Position 8: 2 player(s)
# Position 9: 2 player(s)
# Position 10: 3 player(s)
# Position 11: 2 player(s)
#
#
# Total possible squads (before applying constraints): 384
#
#
# Total valid squads (with exactly 4 foreign players and at least 1 wicketkeeper): 120
#
#
# Top 5 Squads (by total squad score):
#
# Squad 1 (Total Score: 304.29):
#   Position 1: PD Salt - Score: 56.79 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 70.98 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 52.29 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: D Padikkal - Score: 16.04 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 5: JM Sharma - Score: 32.60 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 41.51 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: R Shepherd - Score: 22.53 | Type: AR | Bowler Type: Pace | Nationality: Foreginer
#   Position 8: B Kumar - Score: 20.62 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 9: Rasikh Salam - Score: -3.37 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 10: Yash Dayal - Score: -1.86 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: JR Hazlewood - Score: -3.83 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 2 (Total Score: 299.39):
#   Position 1: PD Salt - Score: 56.79 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 70.98 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 52.29 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: D Padikkal - Score: 16.04 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 5: JM Sharma - Score: 32.60 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 41.51 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: R Shepherd - Score: 22.53 | Type: AR | Bowler Type: Pace | Nationality: Foreginer
#   Position 8: Swapnil Singh - Score: 15.72 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 9: Rasikh Salam - Score: -3.37 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 10: Yash Dayal - Score: -1.86 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: JR Hazlewood - Score: -3.83 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 3 (Total Score: 299.30):
#   Position 1: PD Salt - Score: 56.79 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 70.98 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 52.29 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: D Padikkal - Score: 16.04 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 5: JM Sharma - Score: 32.60 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 41.51 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 17.33 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: B Kumar - Score: 20.62 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 9: N Thushara - Score: -3.16 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   Position 10: Yash Dayal - Score: -1.86 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: JR Hazlewood - Score: -3.83 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 4 (Total Score: 298.82):
#   Position 1: PD Salt - Score: 56.79 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 70.98 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 52.29 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: LS Livingstone - Score: 15.78 | Type: AR | Bowler Type: Spin | Nationality: Foreginer
#   Position 5: JM Sharma - Score: 32.60 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 41.51 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 17.33 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: B Kumar - Score: 20.62 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 9: Rasikh Salam - Score: -3.37 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 10: Yash Dayal - Score: -1.86 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: JR Hazlewood - Score: -3.83 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 5 (Total Score: 297.45):
#   Position 1: PD Salt - Score: 56.79 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 70.98 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 52.29 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: D Padikkal - Score: 16.04 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 5: JM Sharma - Score: 32.60 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 41.51 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 17.33 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: B Kumar - Score: 20.62 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 9: Rasikh Salam - Score: -3.37 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 10: L Ngidi - Score: -3.50 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   Position 11: JR Hazlewood - Score: -3.83 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4

# %% [markdown]
# ## Final code for consistency alone using AHP

# %%
import pandas as pd
import itertools

# Specify the Excel file path and sheet name directly
excel_file_path = "/Users/pavanbandaru/Downloads/cricket-squad-selection/ipl_correct_one copy.xlsx"
sheet_name = "RCB" 

# Read the Excel file and load the specified sheet into a DataFrame
df = pd.read_excel(excel_file_path, sheet_name=sheet_name)

# Calculate score for each player: Score = 0.7 * Form_AHP + 0.3 * Consistency_AHP
df['Score'] = 0 * df['Form_AHP'] + 1 * df['Consistency_AHP']

# Optional: Display players with calculated scores
print("Players with calculated scores:")
print(df[['Player', 'Position', 'Form_AHP', 'Consistency_AHP', 'Score', 'Type', 'Nationality', 'Bowler_Type']])
print("\n")

# Group players by Position (assuming positions 1 to 11)
positions = range(1, 12)
grouped = {pos: df[df['Position'] == pos].to_dict('records')
           for pos in positions if not df[df['Position'] == pos].empty}

# Display available players per position for verification
for pos in positions:
    count = len(grouped[pos]) if pos in grouped else 0
    print(f"Position {pos}: {count} player(s)")
print("\n")

# Generate all possible squad combinations (one player per position)
all_squads = list(itertools.product(*(grouped[pos] for pos in positions)))
print("Total possible squads (before applying constraints):", len(all_squads))
print("\n")

# Filter squads to meet the constraints:
# - Exactly 4 foreign players (Nationality == "Foreginer")
# - At least one wicketkeeper (i.e. 'WK' appears in the "Type" column)
valid_squads = []
for squad in all_squads:
    foreign_count = sum(1 for player in squad if player['Nationality'].strip().lower() == 'foreginer')
    wk_count = sum(1 for player in squad if 'WK' in player['Type'])
    if foreign_count == 4 and wk_count >= 1:
        valid_squads.append(squad)

print("Total valid squads (with exactly 4 foreign players and at least 1 wicketkeeper):", len(valid_squads))
print("\n")

# Sort valid squads by total squad score in descending order.
valid_squads_sorted = sorted(valid_squads,
                             key=lambda squad: sum(player['Score'] for player in squad),
                             reverse=True)

# Select top 5 squads with the highest total score.
top_squads = valid_squads_sorted[:5]

if not top_squads:
    print("No valid squads found meeting all criteria.")
else:
    # Print the top 5 squads with squad details and counts of Indian/Foreigner players.
    print("Top 5 Squads (by total squad score):\n")
    for idx, squad in enumerate(top_squads, start=1):
        squad_score = sum(player['Score'] for player in squad)
        # Count nationality occurrences
        indian_count = sum(1 for player in squad if player['Nationality'].strip().lower() == 'indian')
        foreign_count = sum(1 for player in squad if player['Nationality'].strip().lower() == 'foreginer')
        
        print(f"Squad {idx} (Total Score: {squad_score:.2f}):")
        for player in sorted(squad, key=lambda p: p['Position']):
            print(f"  Position {player['Position']}: {player['Player']} - Score: {player['Score']:.2f} | Type: {player['Type']} | Bowler Type: {player['Bowler_Type']} | Nationality: {player['Nationality']}")
        print(f"  --> Count: Indian = {indian_count}, Foreginer = {foreign_count}\n")
# Out:
# Players with calculated scores:
#             Player  Position   Form_AHP  Consistency_AHP       Score    Type  \
# 0          PD Salt         1  56.787230        67.052939   67.052939  BAT,WK
# 1          V Kohli         2  70.983470       452.085246  452.085246     BAT
# 2       SS Chikara         2  10.556400        10.556397   10.556397     BAT
# 3       RM Patidar         3  52.286320        71.323661   71.323661     BAT
# 4       D Padikkal         4  16.040340       104.713407  104.713407     BAT
# 5   LS Livingstone         4  15.777390       101.354033  101.354033      AR
# 6        JM Sharma         5  32.600720        65.363815   65.363815  BAT,WK
# 7      MS Bhandage         6   9.752964        16.925261   16.925261      AR
# 8         TH David         6  41.507540        66.978910   66.978910     BAT
# 9        KH Pandya         7  17.326540        71.179393   71.179393      AR
# 10      R Shepherd         7  22.528510        18.194121   18.194121      AR
# 11   Swapnil Singh         8  15.721150        10.540120   10.540120      AR
# 12         B Kumar         8  20.620832        39.300988   39.300988    BOWL
# 13    Rasikh Salam         9  -3.374755        -4.556714   -4.556714    BOWL
# 14      N Thushara         9  -3.159281        -3.859281   -3.859281    BOWL
# 15      Yash Dayal        10  -1.862285         0.855878    0.855878    BOWL
# 16         L Ngidi        10  -3.500917         2.748738    2.748738    BOWL
# 17   Suyash Sharma        10 -16.900000        -4.062190   -4.062190    BOWL
# 18    JR Hazlewood        11  -3.831420         4.310629    4.310629    BOWL
# 19    Mohit Rathee        11 -17.081340       -17.081343  -17.081343    BOWL
#
#    Nationality Bowler_Type
# 0    Foreginer         NaN
# 1       Indian         NaN
# 2       Indian         NaN
# 3       Indian         NaN
# 4       Indian         NaN
# 5    Foreginer        Spin
# 6       Indian         NaN
# 7       Indian        Pace
# 8    Foreginer         NaN
# 9       Indian        Spin
# 10   Foreginer        Pace
# 11      Indian        Spin
# 12      Indian        Pace
# 13      Indian        Pace
# 14   Foreginer        Pace
# 15      Indian        Pace
# 16   Foreginer        Pace
# 17      Indian        Spin
# 18   Foreginer        Pace
# 19      Indian        Spin
#
#
# Position 1: 1 player(s)
# Position 2: 2 player(s)
# Position 3: 1 player(s)
# Position 4: 2 player(s)
# Position 5: 1 player(s)
# Position 6: 2 player(s)
# Position 7: 2 player(s)
# Position 8: 2 player(s)
# Position 9: 2 player(s)
# Position 10: 3 player(s)
# Position 11: 2 player(s)
#
#
# Total possible squads (before applying constraints): 384
#
#
# Total valid squads (with exactly 4 foreign players and at least 1 wicketkeeper): 120
#
#
# Top 5 Squads (by total squad score):
#
# Squad 1 (Total Score: 940.50):
#   Position 1: PD Salt - Score: 67.05 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 452.09 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 71.32 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: D Padikkal - Score: 104.71 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 5: JM Sharma - Score: 65.36 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 66.98 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 71.18 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: B Kumar - Score: 39.30 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 9: Rasikh Salam - Score: -4.56 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 10: L Ngidi - Score: 2.75 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   Position 11: JR Hazlewood - Score: 4.31 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 2 (Total Score: 939.31):
#   Position 1: PD Salt - Score: 67.05 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 452.09 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 71.32 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: D Padikkal - Score: 104.71 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 5: JM Sharma - Score: 65.36 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 66.98 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 71.18 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: B Kumar - Score: 39.30 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 9: N Thushara - Score: -3.86 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   Position 10: Yash Dayal - Score: 0.86 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: JR Hazlewood - Score: 4.31 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 3 (Total Score: 935.25):
#   Position 1: PD Salt - Score: 67.05 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 452.09 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 71.32 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: LS Livingstone - Score: 101.35 | Type: AR | Bowler Type: Spin | Nationality: Foreginer
#   Position 5: JM Sharma - Score: 65.36 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 66.98 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 71.18 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: B Kumar - Score: 39.30 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 9: Rasikh Salam - Score: -4.56 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 10: Yash Dayal - Score: 0.86 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: JR Hazlewood - Score: 4.31 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 4 (Total Score: 934.39):
#   Position 1: PD Salt - Score: 67.05 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 452.09 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 71.32 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: D Padikkal - Score: 104.71 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 5: JM Sharma - Score: 65.36 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 66.98 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 71.18 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: B Kumar - Score: 39.30 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 9: N Thushara - Score: -3.86 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   Position 10: Suyash Sharma - Score: -4.06 | Type: BOWL | Bowler Type: Spin | Nationality: Indian
#   Position 11: JR Hazlewood - Score: 4.31 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 5 (Total Score: 930.33):
#   Position 1: PD Salt - Score: 67.05 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 452.09 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 71.32 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: LS Livingstone - Score: 101.35 | Type: AR | Bowler Type: Spin | Nationality: Foreginer
#   Position 5: JM Sharma - Score: 65.36 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 66.98 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 71.18 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: B Kumar - Score: 39.30 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 9: Rasikh Salam - Score: -4.56 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 10: Suyash Sharma - Score: -4.06 | Type: BOWL | Bowler Type: Spin | Nationality: Indian
#   Position 11: JR Hazlewood - Score: 4.31 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4

# %% [markdown]
# ## Final squad code for both consistency and form using PCA

# %%
import pandas as pd
import itertools

# Specify the Excel file path and sheet name directly
excel_file_path = "/Users/pavanbandaru/Downloads/cricket-squad-selection/ipl_correct_one copy.xlsx"
sheet_name = "RCB" 

# Read the Excel file and load the specified sheet into a DataFrame
df = pd.read_excel(excel_file_path, sheet_name=sheet_name)

# Calculate score for each player: Score = 0.7 * Form_PCA + 0.3 * Consistency_PCA
df['Score'] = 0.7 * df['Form_PCA'] + 0.3 * df['Consistency_PCA']

# Optional: Display players with calculated scores
print("Players with calculated scores:")
print(df[['Player', 'Position', 'Form_PCA', 'Consistency_PCA', 'Score', 'Type', 'Nationality', 'Bowler_Type']])
print("\n")

# Group players by Position (assuming positions 1 to 11)
positions = range(1, 12)
grouped = {pos: df[df['Position'] == pos].to_dict('records')
           for pos in positions if not df[df['Position'] == pos].empty}

# Display available players per position for verification
for pos in positions:
    count = len(grouped[pos]) if pos in grouped else 0
    print(f"Position {pos}: {count} player(s)")
print("\n")

# Generate all possible squad combinations (one player per position)
all_squads = list(itertools.product(*(grouped[pos] for pos in positions)))
print("Total possible squads (before applying constraints):", len(all_squads))
print("\n")

# Filter squads to meet the constraints:
# - Exactly 4 foreign players (Nationality == "Foreginer")
# - At least one wicketkeeper (i.e. 'WK' appears in the "Type" column)
valid_squads = []
for squad in all_squads:
    foreign_count = sum(1 for player in squad if player['Nationality'].strip().lower() == 'foreginer')
    wk_count = sum(1 for player in squad if 'WK' in player['Type'])
    if foreign_count == 4 and wk_count >= 1:
        valid_squads.append(squad)

print("Total valid squads (with exactly 4 foreign players and at least 1 wicketkeeper):", len(valid_squads))
print("\n")

# Sort valid squads by total squad score in descending order.
valid_squads_sorted = sorted(valid_squads,
                             key=lambda squad: sum(player['Score'] for player in squad),
                             reverse=True)

# Select top 5 squads with the highest total score.
top_squads = valid_squads_sorted[:5]

if not top_squads:
    print("No valid squads found meeting all criteria.")
else:
    # Print the top 5 squads with squad details and counts of Indian/Foreigner players.
    print("Top 5 Squads (by total squad score):\n")
    for idx, squad in enumerate(top_squads, start=1):
        squad_score = sum(player['Score'] for player in squad)
        # Count nationality occurrences
        indian_count = sum(1 for player in squad if player['Nationality'].strip().lower() == 'indian')
        foreign_count = sum(1 for player in squad if player['Nationality'].strip().lower() == 'foreginer')
        
        print(f"Squad {idx} (Total Score: {squad_score:.2f}):")
        for player in sorted(squad, key=lambda p: p['Position']):
            print(f"  Position {player['Position']}: {player['Player']} - Score: {player['Score']:.2f} | Type: {player['Type']} | Bowler Type: {player['Bowler_Type']} | Nationality: {player['Nationality']}")
        print(f"  --> Count: Indian = {indian_count}, Foreginer = {foreign_count}\n")
# Out:
# Players with calculated scores:
#             Player  Position    Form_PCA  Consistency_PCA       Score    Type  \
# 0          PD Salt         1  117.581370       142.532160  125.066607  BAT,WK
# 1          V Kohli         2  176.382490      1606.571507  605.439195     BAT
# 2       SS Chikara         2   10.508518         4.487546    8.702226     BAT
# 3       RM Patidar         3  105.123880       168.145551  124.030381     BAT
# 4       D Padikkal         4   16.585913       318.969067  107.300859     BAT
# 5   LS Livingstone         4   10.777063       300.560097   97.711973      AR
# 6        JM Sharma         5   54.841621       151.931855   83.968691  BAT,WK
# 7      MS Bhandage         6    4.962275        14.628897    7.862261      AR
# 8         TH David         6   71.171688       138.857622   91.477468     BAT
# 9        KH Pandya         7   13.232199       110.277887   42.345906      AR
# 10      R Shepherd         7    6.834181         9.933095    7.763855      AR
# 11   Swapnil Singh         8    6.977548         4.963966    6.373473      AR
# 12         B Kumar         8   22.753512        39.818326   27.872956    BOWL
# 13    Rasikh Salam         9   -3.834037        -3.257874   -3.661188    BOWL
# 14      N Thushara         9   -6.306704        -5.430504   -6.043844    BOWL
# 15      Yash Dayal        10   -4.564430        -0.703645   -3.406194    BOWL
# 16         L Ngidi        11   -5.538020         4.824896   -2.429145    BOWL
# 17   Suyash Sharma        10  -21.855520        -5.625815  -16.986608    BOWL
# 18    JR Hazlewood        11   -5.688512         3.221351   -3.015553    BOWL
# 19    Mohit Rathee        11  -22.123160       -20.131391  -21.525629    BOWL
#
#    Nationality Bowler_Type
# 0    Foreginer         NaN
# 1       Indian         NaN
# 2       Indian         NaN
# 3       Indian         NaN
# 4       Indian         NaN
# 5    Foreginer        Spin
# 6       Indian         NaN
# 7       Indian        Pace
# 8    Foreginer         NaN
# 9       Indian        Spin
# 10   Foreginer        Pace
# 11      Indian        Spin
# 12      Indian        Pace
# 13      Indian        Pace
# 14   Foreginer        Pace
# 15      Indian        Pace
# 16   Foreginer        Pace
# 17      Indian        Spin
# 18   Foreginer        Pace
# 19      Indian        Spin
#
#
# Position 1: 1 player(s)
# Position 2: 2 player(s)
# Position 3: 1 player(s)
# Position 4: 2 player(s)
# Position 5: 1 player(s)
# Position 6: 2 player(s)
# Position 7: 2 player(s)
# Position 8: 2 player(s)
# Position 9: 2 player(s)
# Position 10: 2 player(s)
# Position 11: 3 player(s)
#
#
# Total possible squads (before applying constraints): 384
#
#
# Total valid squads (with exactly 4 foreign players and at least 1 wicketkeeper): 128
#
#
# Top 5 Squads (by total squad score):
#
# Squad 1 (Total Score: 1195.62):
#   Position 1: PD Salt - Score: 125.07 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 605.44 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 124.03 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: D Padikkal - Score: 107.30 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 5: JM Sharma - Score: 83.97 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 91.48 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 42.35 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: B Kumar - Score: 27.87 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 9: N Thushara - Score: -6.04 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   Position 10: Yash Dayal - Score: -3.41 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: L Ngidi - Score: -2.43 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 2 (Total Score: 1195.04):
#   Position 1: PD Salt - Score: 125.07 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 605.44 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 124.03 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: D Padikkal - Score: 107.30 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 5: JM Sharma - Score: 83.97 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 91.48 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 42.35 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: B Kumar - Score: 27.87 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 9: N Thushara - Score: -6.04 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   Position 10: Yash Dayal - Score: -3.41 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: JR Hazlewood - Score: -3.02 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 3 (Total Score: 1188.42):
#   Position 1: PD Salt - Score: 125.07 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 605.44 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 124.03 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: LS Livingstone - Score: 97.71 | Type: AR | Bowler Type: Spin | Nationality: Foreginer
#   Position 5: JM Sharma - Score: 83.97 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 91.48 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 42.35 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: B Kumar - Score: 27.87 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 9: Rasikh Salam - Score: -3.66 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 10: Yash Dayal - Score: -3.41 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: L Ngidi - Score: -2.43 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 4 (Total Score: 1187.83):
#   Position 1: PD Salt - Score: 125.07 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 605.44 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 124.03 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: LS Livingstone - Score: 97.71 | Type: AR | Bowler Type: Spin | Nationality: Foreginer
#   Position 5: JM Sharma - Score: 83.97 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 91.48 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 42.35 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: B Kumar - Score: 27.87 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 9: Rasikh Salam - Score: -3.66 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 10: Yash Dayal - Score: -3.41 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: JR Hazlewood - Score: -3.02 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 5 (Total Score: 1182.04):
#   Position 1: PD Salt - Score: 125.07 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 605.44 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 124.03 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: D Padikkal - Score: 107.30 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 5: JM Sharma - Score: 83.97 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 91.48 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 42.35 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: B Kumar - Score: 27.87 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 9: N Thushara - Score: -6.04 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   Position 10: Suyash Sharma - Score: -16.99 | Type: BOWL | Bowler Type: Spin | Nationality: Indian
#   Position 11: L Ngidi - Score: -2.43 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4

# %% [markdown]
# ## Final squad code for consistency using PCA

# %%
import pandas as pd
import itertools

# Specify the Excel file path and sheet name directly
excel_file_path = "/Users/pavanbandaru/Downloads/cricket-squad-selection/ipl_correct_one copy.xlsx"
sheet_name = "RCB" 

# Read the Excel file and load the specified sheet into a DataFrame
df = pd.read_excel(excel_file_path, sheet_name=sheet_name)

# Calculate score for each player: Score = 0.7 * Form_PCA + 0.3 * Consistency_PCA
df['Score'] = 0 * df['Form_PCA'] + 1 * df['Consistency_PCA']

# Optional: Display players with calculated scores
print("Players with calculated scores:")
print(df[['Player', 'Position', 'Form_PCA', 'Consistency_PCA', 'Score', 'Type', 'Nationality', 'Bowler_Type']])
print("\n")

# Group players by Position (assuming positions 1 to 11)
positions = range(1, 12)
grouped = {pos: df[df['Position'] == pos].to_dict('records')
           for pos in positions if not df[df['Position'] == pos].empty}

# Display available players per position for verification
for pos in positions:
    count = len(grouped[pos]) if pos in grouped else 0
    print(f"Position {pos}: {count} player(s)")
print("\n")

# Generate all possible squad combinations (one player per position)
all_squads = list(itertools.product(*(grouped[pos] for pos in positions)))
print("Total possible squads (before applying constraints):", len(all_squads))
print("\n")

# Filter squads to meet the constraints:
# - Exactly 4 foreign players (Nationality == "Foreginer")
# - At least one wicketkeeper (i.e. 'WK' appears in the "Type" column)
valid_squads = []
for squad in all_squads:
    foreign_count = sum(1 for player in squad if player['Nationality'].strip().lower() == 'foreginer')
    wk_count = sum(1 for player in squad if 'WK' in player['Type'])
    if foreign_count == 4 and wk_count >= 1:
        valid_squads.append(squad)

print("Total valid squads (with exactly 4 foreign players and at least 1 wicketkeeper):", len(valid_squads))
print("\n")

# Sort valid squads by total squad score in descending order.
valid_squads_sorted = sorted(valid_squads,
                             key=lambda squad: sum(player['Score'] for player in squad),
                             reverse=True)

# Select top 5 squads with the highest total score.
top_squads = valid_squads_sorted[:5]

if not top_squads:
    print("No valid squads found meeting all criteria.")
else:
    # Print the top 5 squads with squad details and counts of Indian/Foreigner players.
    print("Top 5 Squads (by total squad score):\n")
    for idx, squad in enumerate(top_squads, start=1):
        squad_score = sum(player['Score'] for player in squad)
        # Count nationality occurrences
        indian_count = sum(1 for player in squad if player['Nationality'].strip().lower() == 'indian')
        foreign_count = sum(1 for player in squad if player['Nationality'].strip().lower() == 'foreginer')
        
        print(f"Squad {idx} (Total Score: {squad_score:.2f}):")
        for player in sorted(squad, key=lambda p: p['Position']):
            print(f"  Position {player['Position']}: {player['Player']} - Score: {player['Score']:.2f} | Type: {player['Type']} | Bowler Type: {player['Bowler_Type']} | Nationality: {player['Nationality']}")
        print(f"  --> Count: Indian = {indian_count}, Foreginer = {foreign_count}\n")
# Out:
# Players with calculated scores:
#             Player  Position    Form_PCA  Consistency_PCA        Score  \
# 0          PD Salt         1  117.581370       142.532160   142.532160
# 1          V Kohli         2  176.382490      1606.571507  1606.571507
# 2       SS Chikara         2   10.508518         4.487546     4.487546
# 3       RM Patidar         3  105.123880       168.145551   168.145551
# 4       D Padikkal         4   16.585913       318.969067   318.969067
# 5   LS Livingstone         4   10.777063       300.560097   300.560097
# 6        JM Sharma         5   54.841621       151.931855   151.931855
# 7      MS Bhandage         6    4.962275        14.628897    14.628897
# 8         TH David         6   71.171688       138.857622   138.857622
# 9        KH Pandya         7   13.232199       110.277887   110.277887
# 10      R Shepherd         7    6.834181         9.933095     9.933095
# 11   Swapnil Singh         8    6.977548         4.963966     4.963966
# 12         B Kumar         8   22.753512        39.818326    39.818326
# 13    Rasikh Salam         9   -3.834037        -3.257874    -3.257874
# 14      N Thushara         9   -6.306704        -5.430504    -5.430504
# 15      Yash Dayal        10   -4.564430        -0.703645    -0.703645
# 16         L Ngidi        11   -5.538020         4.824896     4.824896
# 17   Suyash Sharma        10  -21.855520        -5.625815    -5.625815
# 18    JR Hazlewood        11   -5.688512         3.221351     3.221351
# 19    Mohit Rathee        11  -22.123160       -20.131391   -20.131391
#
#       Type Nationality Bowler_Type
# 0   BAT,WK   Foreginer         NaN
# 1      BAT      Indian         NaN
# 2      BAT      Indian         NaN
# 3      BAT      Indian         NaN
# 4      BAT      Indian         NaN
# 5       AR   Foreginer        Spin
# 6   BAT,WK      Indian         NaN
# 7       AR      Indian        Pace
# 8      BAT   Foreginer         NaN
# 9       AR      Indian        Spin
# 10      AR   Foreginer        Pace
# 11      AR      Indian        Spin
# 12    BOWL      Indian        Pace
# 13    BOWL      Indian        Pace
# 14    BOWL   Foreginer        Pace
# 15    BOWL      Indian        Pace
# 16    BOWL   Foreginer        Pace
# 17    BOWL      Indian        Spin
# 18    BOWL   Foreginer        Pace
# 19    BOWL      Indian        Spin
#
#
# Position 1: 1 player(s)
# Position 2: 2 player(s)
# Position 3: 1 player(s)
# Position 4: 2 player(s)
# Position 5: 1 player(s)
# Position 6: 2 player(s)
# Position 7: 2 player(s)
# Position 8: 2 player(s)
# Position 9: 2 player(s)
# Position 10: 2 player(s)
# Position 11: 3 player(s)
#
#
# Total possible squads (before applying constraints): 384
#
#
# Total valid squads (with exactly 4 foreign players and at least 1 wicketkeeper): 128
#
#
# Top 5 Squads (by total squad score):
#
# Squad 1 (Total Score: 2675.79):
#   Position 1: PD Salt - Score: 142.53 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 1606.57 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 168.15 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: D Padikkal - Score: 318.97 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 5: JM Sharma - Score: 151.93 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 138.86 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 110.28 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: B Kumar - Score: 39.82 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 9: N Thushara - Score: -5.43 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   Position 10: Yash Dayal - Score: -0.70 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: L Ngidi - Score: 4.82 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 2 (Total Score: 2674.19):
#   Position 1: PD Salt - Score: 142.53 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 1606.57 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 168.15 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: D Padikkal - Score: 318.97 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 5: JM Sharma - Score: 151.93 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 138.86 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 110.28 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: B Kumar - Score: 39.82 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 9: N Thushara - Score: -5.43 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   Position 10: Yash Dayal - Score: -0.70 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: JR Hazlewood - Score: 3.22 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 3 (Total Score: 2670.87):
#   Position 1: PD Salt - Score: 142.53 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 1606.57 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 168.15 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: D Padikkal - Score: 318.97 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 5: JM Sharma - Score: 151.93 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 138.86 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 110.28 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: B Kumar - Score: 39.82 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 9: N Thushara - Score: -5.43 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   Position 10: Suyash Sharma - Score: -5.63 | Type: BOWL | Bowler Type: Spin | Nationality: Indian
#   Position 11: L Ngidi - Score: 4.82 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 4 (Total Score: 2669.27):
#   Position 1: PD Salt - Score: 142.53 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 1606.57 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 168.15 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: D Padikkal - Score: 318.97 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 5: JM Sharma - Score: 151.93 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 138.86 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 110.28 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: B Kumar - Score: 39.82 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 9: N Thushara - Score: -5.43 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   Position 10: Suyash Sharma - Score: -5.63 | Type: BOWL | Bowler Type: Spin | Nationality: Indian
#   Position 11: JR Hazlewood - Score: 3.22 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 5 (Total Score: 2659.56):
#   Position 1: PD Salt - Score: 142.53 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 1606.57 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 168.15 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: LS Livingstone - Score: 300.56 | Type: AR | Bowler Type: Spin | Nationality: Foreginer
#   Position 5: JM Sharma - Score: 151.93 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 138.86 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 110.28 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: B Kumar - Score: 39.82 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 9: Rasikh Salam - Score: -3.26 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 10: Yash Dayal - Score: -0.70 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: L Ngidi - Score: 4.82 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4

# %% [markdown]
# ## Final squad code for form using PCA

# %%
import pandas as pd
import itertools

# Specify the Excel file path and sheet name directly
excel_file_path = "/Users/pavanbandaru/Downloads/cricket-squad-selection/ipl_correct_one copy.xlsx"
sheet_name = "RCB" 

# Read the Excel file and load the specified sheet into a DataFrame
df = pd.read_excel(excel_file_path, sheet_name=sheet_name)

# Calculate score for each player: Score = 0.7 * Form_PCA + 0.3 * Consistency_PCA
df['Score'] = 1 * df['Form_PCA'] + 0 * df['Consistency_PCA']

# Optional: Display players with calculated scores
print("Players with calculated scores:")
print(df[['Player', 'Position', 'Form_PCA', 'Consistency_PCA', 'Score', 'Type', 'Nationality', 'Bowler_Type']])
print("\n")

# Group players by Position (assuming positions 1 to 11)
positions = range(1, 12)
grouped = {pos: df[df['Position'] == pos].to_dict('records')
           for pos in positions if not df[df['Position'] == pos].empty}

# Display available players per position for verification
for pos in positions:
    count = len(grouped[pos]) if pos in grouped else 0
    print(f"Position {pos}: {count} player(s)")
print("\n")

# Generate all possible squad combinations (one player per position)
all_squads = list(itertools.product(*(grouped[pos] for pos in positions)))
print("Total possible squads (before applying constraints):", len(all_squads))
print("\n")

# Filter squads to meet the constraints:
# - Exactly 4 foreign players (Nationality == "Foreginer")
# - At least one wicketkeeper (i.e. 'WK' appears in the "Type" column)
valid_squads = []
for squad in all_squads:
    foreign_count = sum(1 for player in squad if player['Nationality'].strip().lower() == 'foreginer')
    wk_count = sum(1 for player in squad if 'WK' in player['Type'])
    if foreign_count == 4 and wk_count >= 1:
        valid_squads.append(squad)

print("Total valid squads (with exactly 4 foreign players and at least 1 wicketkeeper):", len(valid_squads))
print("\n")

# Sort valid squads by total squad score in descending order.
valid_squads_sorted = sorted(valid_squads,
                             key=lambda squad: sum(player['Score'] for player in squad),
                             reverse=True)

# Select top 5 squads with the highest total score.
top_squads = valid_squads_sorted[:5]

if not top_squads:
    print("No valid squads found meeting all criteria.")
else:
    # Print the top 5 squads with squad details and counts of Indian/Foreigner players.
    print("Top 5 Squads (by total squad score):\n")
    for idx, squad in enumerate(top_squads, start=1):
        squad_score = sum(player['Score'] for player in squad)
        # Count nationality occurrences
        indian_count = sum(1 for player in squad if player['Nationality'].strip().lower() == 'indian')
        foreign_count = sum(1 for player in squad if player['Nationality'].strip().lower() == 'foreginer')
        
        print(f"Squad {idx} (Total Score: {squad_score:.2f}):")
        for player in sorted(squad, key=lambda p: p['Position']):
            print(f"  Position {player['Position']}: {player['Player']} - Score: {player['Score']:.2f} | Type: {player['Type']} | Bowler Type: {player['Bowler_Type']} | Nationality: {player['Nationality']}")
        print(f"  --> Count: Indian = {indian_count}, Foreginer = {foreign_count}\n")
# Out:
# Players with calculated scores:
#             Player  Position    Form_PCA  Consistency_PCA       Score    Type  \
# 0          PD Salt         1  117.581370       142.532160  117.581370  BAT,WK
# 1          V Kohli         2  176.382490      1606.571507  176.382490     BAT
# 2       SS Chikara         2   10.508518         4.487546   10.508518     BAT
# 3       RM Patidar         3  105.123880       168.145551  105.123880     BAT
# 4       D Padikkal         4   16.585913       318.969067   16.585913     BAT
# 5   LS Livingstone         4   10.777063       300.560097   10.777063      AR
# 6        JM Sharma         5   54.841621       151.931855   54.841621  BAT,WK
# 7      MS Bhandage         6    4.962275        14.628897    4.962275      AR
# 8         TH David         6   71.171688       138.857622   71.171688     BAT
# 9        KH Pandya         7   13.232199       110.277887   13.232199      AR
# 10      R Shepherd         7    6.834181         9.933095    6.834181      AR
# 11   Swapnil Singh         8    6.977548         4.963966    6.977548      AR
# 12         B Kumar         8   22.753512        39.818326   22.753512    BOWL
# 13    Rasikh Salam         9   -3.834037        -3.257874   -3.834037    BOWL
# 14      N Thushara         9   -6.306704        -5.430504   -6.306704    BOWL
# 15      Yash Dayal        10   -4.564430        -0.703645   -4.564430    BOWL
# 16         L Ngidi        11   -5.538020         4.824896   -5.538020    BOWL
# 17   Suyash Sharma        10  -21.855520        -5.625815  -21.855520    BOWL
# 18    JR Hazlewood        11   -5.688512         3.221351   -5.688512    BOWL
# 19    Mohit Rathee        11  -22.123160       -20.131391  -22.123160    BOWL
#
#    Nationality Bowler_Type
# 0    Foreginer         NaN
# 1       Indian         NaN
# 2       Indian         NaN
# 3       Indian         NaN
# 4       Indian         NaN
# 5    Foreginer        Spin
# 6       Indian         NaN
# 7       Indian        Pace
# 8    Foreginer         NaN
# 9       Indian        Spin
# 10   Foreginer        Pace
# 11      Indian        Spin
# 12      Indian        Pace
# 13      Indian        Pace
# 14   Foreginer        Pace
# 15      Indian        Pace
# 16   Foreginer        Pace
# 17      Indian        Spin
# 18   Foreginer        Pace
# 19      Indian        Spin
#
#
# Position 1: 1 player(s)
# Position 2: 2 player(s)
# Position 3: 1 player(s)
# Position 4: 2 player(s)
# Position 5: 1 player(s)
# Position 6: 2 player(s)
# Position 7: 2 player(s)
# Position 8: 2 player(s)
# Position 9: 2 player(s)
# Position 10: 2 player(s)
# Position 11: 3 player(s)
#
#
# Total possible squads (before applying constraints): 384
#
#
# Total valid squads (with exactly 4 foreign players and at least 1 wicketkeeper): 128
#
#
# Top 5 Squads (by total squad score):
#
# Squad 1 (Total Score: 561.26):
#   Position 1: PD Salt - Score: 117.58 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 176.38 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 105.12 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: D Padikkal - Score: 16.59 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 5: JM Sharma - Score: 54.84 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 71.17 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 13.23 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: B Kumar - Score: 22.75 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 9: N Thushara - Score: -6.31 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   Position 10: Yash Dayal - Score: -4.56 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: L Ngidi - Score: -5.54 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 2 (Total Score: 561.11):
#   Position 1: PD Salt - Score: 117.58 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 176.38 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 105.12 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: D Padikkal - Score: 16.59 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 5: JM Sharma - Score: 54.84 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 71.17 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 13.23 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: B Kumar - Score: 22.75 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 9: N Thushara - Score: -6.31 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   Position 10: Yash Dayal - Score: -4.56 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: JR Hazlewood - Score: -5.69 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 3 (Total Score: 557.93):
#   Position 1: PD Salt - Score: 117.58 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 176.38 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 105.12 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: LS Livingstone - Score: 10.78 | Type: AR | Bowler Type: Spin | Nationality: Foreginer
#   Position 5: JM Sharma - Score: 54.84 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 71.17 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 13.23 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: B Kumar - Score: 22.75 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 9: Rasikh Salam - Score: -3.83 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 10: Yash Dayal - Score: -4.56 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: L Ngidi - Score: -5.54 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 4 (Total Score: 557.78):
#   Position 1: PD Salt - Score: 117.58 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 176.38 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 105.12 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: LS Livingstone - Score: 10.78 | Type: AR | Bowler Type: Spin | Nationality: Foreginer
#   Position 5: JM Sharma - Score: 54.84 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 71.17 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: KH Pandya - Score: 13.23 | Type: AR | Bowler Type: Spin | Nationality: Indian
#   Position 8: B Kumar - Score: 22.75 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 9: Rasikh Salam - Score: -3.83 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 10: Yash Dayal - Score: -4.56 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: JR Hazlewood - Score: -5.69 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4
#
# Squad 5 (Total Score: 557.34):
#   Position 1: PD Salt - Score: 117.58 | Type: BAT,WK | Bowler Type: nan | Nationality: Foreginer
#   Position 2: V Kohli - Score: 176.38 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 3: RM Patidar - Score: 105.12 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 4: D Padikkal - Score: 16.59 | Type: BAT | Bowler Type: nan | Nationality: Indian
#   Position 5: JM Sharma - Score: 54.84 | Type: BAT,WK | Bowler Type: nan | Nationality: Indian
#   Position 6: TH David - Score: 71.17 | Type: BAT | Bowler Type: nan | Nationality: Foreginer
#   Position 7: R Shepherd - Score: 6.83 | Type: AR | Bowler Type: Pace | Nationality: Foreginer
#   Position 8: B Kumar - Score: 22.75 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 9: Rasikh Salam - Score: -3.83 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 10: Yash Dayal - Score: -4.56 | Type: BOWL | Bowler Type: Pace | Nationality: Indian
#   Position 11: L Ngidi - Score: -5.54 | Type: BOWL | Bowler Type: Pace | Nationality: Foreginer
#   --> Count: Indian = 7, Foreginer = 4
